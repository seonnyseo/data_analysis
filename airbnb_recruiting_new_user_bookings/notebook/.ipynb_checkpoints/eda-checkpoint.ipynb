# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %%
from collections import defaultdict

# %%
df_train = pd.read_csv('../data/train_users.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
len(df_train.date_first_booking.dropna())
# Out:
# 88908

# %%
len(df_train.loc[df_train.country_destination != 'NDF'])
# Out:
# 88908

# %%
#df_train = df_train.drop(columns = ['date_first_booking'], axis = 1)

# %% [markdown]
# DatetimeIndex

# %%
#df_train['date_account_created'] = pd.to_datetime(date_account_created, format='%Y-%m-%d', errors='ignore')
df_train['account_created_year'] = pd.DatetimeIndex(df_train['date_account_created']).year
df_train['account_created_month'] = pd.DatetimeIndex(df_train['date_account_created']).month
df_train['account_created_day'] = pd.DatetimeIndex(df_train['date_account_created']).day
df_train = df_train.drop(['date_account_created'], axis = 1)

# %%
y = df_train.groupby('account_created_year').size()
x = y.index

plt.figure(figsize=(16,4))
plt.bar(x, y)
plt.show()

# %% [markdown]
# df.groupby().size()

# %%
year_month = df_train.groupby(['account_created_year', 'account_created_month']).size()

# %%
from collections import defaultdict

# %% [markdown]
# defaultdict(lambda :) -> lambda 작성하는 법

# %%
account_year_month = defaultdict(lambda: [-1 for x in range(13)])
for idx, val in zip(year_month.index, year_month):
    year = idx[0]
    month = idx[1]
    account_year_month[year][month] = val

# %%
fig, axes = plt.subplots(len(account_year_month.keys()), 1)

for year, ax in zip(account_year_month.keys(), axes):
    
    vals = account_year_month[year]
    start = next(x for x, val in enumerate(vals) if val != -1)
    end = next(x for x, val in enumerate(vals[::-1]) if val != -1)
    
    start = start if start != 0 else 1
    end = end if end != 0 else 13

    ax.plot([m for m in range(len(vals))], vals)
    ax.set_title(year, loc = 'left')

# %%
def draw_line_plot(data):
    
    for year in data.keys():
        start = next(x for x, val in enumerate(data[year]) if val != -1)
        end = next(x for x, val in enumerate(data[year][::-1]) if val != -1)

        start = start if start != 0 else 1
        end = end if end != 0 else 13
        
        plt.plot([x for x in range(start, end)], data[year][start:end], label = year)
    
    plt.xticks([x for x in range(start, end)])

# %%
draw_line_plot(account_year_month)

# %%
activation = pd.DataFrame(df_train.groupby(['account_created_year', 'account_created_month']).size())
activation = activation.rename(columns = {0:'number_of_users'})

# %%
plt.figure(figsize=(16, 5))  
x = ['{}-{:02}'.format(y, m) for (y, m) in activation.index]
y = activation['number_of_users']
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.show()

# %%
df_train.affiliate_channel.unique()
# Out:
# array(['direct', 'seo', 'other', 'sem-non-brand', 'content', 'sem-brand',
#        'remarketing', 'api'], dtype=object)

# %%
affi_channel_month = df_train.groupby(['account_created_year', 'account_created_month','affiliate_channel']).size().unstack()
affi_channel_month = affi_channel_month.fillna(0)

# %%
month_range = ['{}-{:02}'.format(y, m) for (y, m) in affi_channel_month.index]

# %%
channel_count = defaultdict(list)
for channel in affi_channel_month.columns:
    for m in range(len(affi_channel_month[channel])):
        count = affi_channel_month[channel][m]
        channel_count[channel].append(count)

# %%
for channel in channel_count.keys():
    plt.plot(month_range, channel_count[channel], label = channel)
plt.xticks(rotation = 90)
plt.legend(framealpha=1, frameon=True);
plt.grid(alpha=0.5)
plt.show()

# %%
count_by_month = pd.DataFrame.from_dict(channel_count, orient = 'index', columns = x)

# %%
add = pd.DataFrame([])
for idx in range(1, len(x)):
    previous = month_range[idx - 1]
    current = month_range[idx]
    add = pd.concat([add, pd.DataFrame(count_by_month[current] / count_by_month[previous], columns = [current])], axis = 1)

# %%
def color_negative_red(value):
    """
    Colors elements in a dateframe
    green if positive and red if
    negative. Does not color NaN
    values.
    """
    
    if value == 0:
        color = 'black'
    elif value >= 1:
        color = 'red'
    else:
        color = 'blue'
    return 'color: %s'%color

# %%
add.replace(np.inf, np.nan).round(2).fillna(0).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col0 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col1 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col2 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col3 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col4 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col5 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col6 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col7 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col8 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col9 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col10 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col11 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col12 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col13 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col14 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col15 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col16 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col17 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col18 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col19 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col20 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col21 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col22 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col23 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col24 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col25 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col26 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col27 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col28 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col29 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col30 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col31 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col32 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col33 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col34 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col35 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col36 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col37 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col38 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col39 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col40 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col41 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col42 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col43 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col44 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col45 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col46 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col47 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col48 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col49 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col50 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col51 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row0_col52 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col0 {
#             color:  black;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col1 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col2 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col3 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col4 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col5 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col6 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col7 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col8 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col9 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col10 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col11 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col12 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col13 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col14 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col15 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col16 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col17 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col18 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col19 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col20 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col21 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col22 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col23 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col24 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col25 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col26 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col27 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col28 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col29 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col30 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col31 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col32 {
#             color:  blue;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col33 {
#             color:  red;
#         }    #T_52aca648_8cb7_11ea_a8c4_acde48001122row1_col34 {
#             color:  red;

# %%
y = df_train.age.dropna().value_counts()
x = y.index

# %%
plt.bar(x, y)
plt.yscale("log")

# %% [markdown]
# use of loc

# %%
age_mask = df_train.age > 1000
df_train.loc[age_mask, 'age'] = 2015 - df_train.loc[age_mask, 'age']

# %%
df_train.loc[(df_train.age > 100) | (df_train.age < 18), 'age'] = -1
df_train.age.fillna(-1, inplace = True)

# %%
y = df_train.loc[df_train.age != -1, 'age'].value_counts()
x = y.index

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 83 artists>

# %%
gender_destination = pd.crosstab(df_train.gender, df_train.country_destination, normalize = True)
gender_destination['SUM'] = gender_destination.agg(np.sum, axis = 1)
gender_destination.loc['SUM'] = gender_destination.sum()
gender_destination
# Out:
# country_destination        AU        CA        DE        ES        FR  \
# gender
# -unknown-            0.000670  0.002300  0.001331  0.003350  0.008025
# FEMALE               0.000970  0.002132  0.001677  0.003996  0.009192
# MALE                 0.000881  0.002235  0.001949  0.003172  0.006254
# OTHER                0.000005  0.000023  0.000014  0.000019  0.000061
# SUM                  0.002525  0.006690  0.004971  0.010536  0.023532
#
# country_destination        GB        IT       NDF        NL        PT  \
# gender
# -unknown-            0.003551  0.004872  0.312343  0.001063  0.000323
# FEMALE               0.004127  0.005111  0.145457  0.001190  0.000365
# MALE                 0.003195  0.003275  0.125176  0.001302  0.000323
# OTHER                0.000014  0.000023  0.000497  0.000014  0.000005
# SUM                  0.010888  0.013282  0.583473  0.003570  0.001017
#
# country_destination        US     other       SUM
# gender
# -unknown-            0.094209  0.016252  0.448290
# FEMALE               0.106319  0.014804  0.295342
# MALE                 0.091154  0.016130  0.255047
# OTHER                0.000543  0.000103  0.001321
# SUM                  0.292226  0.047290  1.000000

# %%
destination_by_gender = pd.DataFrame([])
for gender in df_train.gender.unique():
    gender_mask = df_train.gender == gender
    destination_by_gender = destination_by_gender.append(df_train.loc[gender_mask, 'country_destination'].value_counts(normalize = True).rename(gender))
destination_by_gender['SUM'] = destination_by_gender.agg(np.sum, axis = 1)

# %%
destination_by_gender
# Out:
#                  AU        CA        DE        ES        FR        GB  \
# -unknown-  0.001494  0.005131  0.002968  0.007472  0.017902  0.007922
# MALE       0.003453  0.008762  0.007641  0.012436  0.024522  0.012528
# FEMALE     0.003284  0.007218  0.005679  0.013531  0.031123  0.013975
# OTHER      0.003546  0.017730  0.010638  0.014184  0.046099  0.010638
#
#                  IT       NDF        NL        PT        US     other  SUM
# -unknown-  0.010869  0.696744  0.002372  0.000721  0.210152  0.036253  1.0
# MALE       0.012840  0.490797  0.005107  0.001267  0.357403  0.063244  1.0
# FEMALE     0.017306  0.492505  0.004029  0.001237  0.359988  0.050126  1.0
# OTHER      0.017730  0.375887  0.010638  0.003546  0.411348  0.078014  1.0

# %%
pd.crosstab(df_train['country_destination'], df_train['gender']).plot.bar()

# %%
gender_country = defaultdict(list)
for gender in df_train.gender.unique():
    gender_country[gender] = df_train.loc[df_train.gender == gender, 'country_destination'].value_counts()

# %%
barWidth = 0.25

colors = ['#0F4C81', '#F5B895', '#77202F', '#E38690']


r1 = np.arange(len(gender_country['-unknown-']))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

plt.bar(r1, gender_country['-unknown-'], color='#F67280', width=barWidth, edgecolor='white', label='UNKNOWN')
plt.bar(r2, gender_country['FEMALE'], color='#C06C84', width=barWidth, edgecolor='white', label='FEMALE')
plt.bar(r3, gender_country['MALE'], color='#6C5B7B', width=barWidth, edgecolor='white', label='MALE')
plt.bar(r4, gender_country['OTHER'] , color='#355C7D', width=barWidth, edgecolor='white', label='OTHER')

plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(gender_country['FEMALE']))], df_train.country_destination.unique())
plt.legend(framealpha=1, frameon=True);
plt.show()

# %%
pd.crosstab(df_train.gender, df_train.first_device_type).plot.bar()

# %%
#gender_mask = (df_train.gender == '-unknown-')
age_mask = (df_train.age != -1)

# %%
df_train.loc[age_mask, 'gender'].value_counts()
# Out:
# FEMALE       56695
# MALE         49949
# -unknown-    16119
# OTHER          224
# Name: gender, dtype: int64

# %%
age_mask = (df_train.age == -1)
df_train.loc[age_mask, 'gender'].value_counts()
# Out:
# -unknown-    79569
# FEMALE        6346
# MALE          4491
# OTHER           58
# Name: gender, dtype: int64

# %% [markdown]
# Session Data

# %%
sessions = pd.read_csv('../data/sessions.csv')

# %%
sessions.head(4)
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
sessions = sessions.rename(columns = {'user_id':'id'})

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
booked_users_id = df_train.loc[pd.notnull(df_train.date_first_booking), 'id']

# %%
booked_users = sessions.loc[sessions.id.isin(booked_users_id)]
unbooked_users = sessions.loc[~sessions.id.isin(booked_users_id)]

# %%
booked_users.groupby('id').size().agg({
    'actions_total':np.sum,
    'actions_mean':np.mean,
    'actions_median':np.median,
    'actions_std':np.std,
    'actions_max':np.max,
    'actions_min':np.min
})
# Out:
# actions_total     2.480247e+06
# actions_mean      8.619750e+01
# actions_median    4.500000e+01
# actions_std       1.252253e+02
# actions_max       2.644000e+03
# actions_min       1.000000e+00
# dtype: float64

# %%
unbooked_users.groupby('id').size().agg({
    'actions_total':np.sum,
    'actions_mean':np.mean,
    'actions_median':np.median,
    'actions_std':np.std,
    'actions_max':np.max,
    'actions_min':np.min
})
# Out:
# actions_total     8.052994e+06
# actions_mean      7.546687e+01
# actions_median    4.000000e+01
# actions_std       1.087861e+02
# actions_max       2.722000e+03
# actions_min       1.000000e+00
# dtype: float64

# %%
sessions.groupby()

# %%
_agg = booked_users.groupby('id')['secs_elapsed']

# %%
booked_users_elapsed.day.median()
# Out:
# 13.762100694444442

# %%
y = booked_users_elapsed.day.to_list()
plt.hist(y, bins = 500)
plt.show()

# %%
y = unbooked_users_elapsed.day.to_list()
plt.hist(y, bins = 500)
plt.show()

# %%
unbooked_users_elapsed = unbooked_users.groupby('id')['secs_elapsed'].agg(['sum', ('day', lambda x: np.sum(x)/60/60/24)]).sort_values(by = 'day')

# %%
unbooked_users_elapsed.day.median()
# Out:
# 8.826215277777779

# %%
df_train.columns
# Out:
# Index(['id', 'timestamp_first_active', 'date_first_booking', 'gender', 'age',
#        'signup_method', 'signup_flow', 'language', 'affiliate_channel',
#        'affiliate_provider', 'first_affiliate_tracked', 'signup_app',
#        'first_device_type', 'first_browser', 'country_destination',
#        'account_created_year', 'account_created_month', 'account_created_day'],
#       dtype='object')

# %%
booked_users_id
# Out:
# 2         4ft3gnwmtx
# 3         bjjt8pjhuk
# 4         87mebub9p4
# 5         osr2jwljor
# 6         lsw9q7uk0j
#              ...
# 213415    7plqriggxp
# 213439    msucfwmlzc
# 213441    omlc9iku7t
# 213443    0k26r3mir0
# 213445    qbxza0xojf
# Name: id, Length: 88908, dtype: object

# %% [markdown]
# '4ft3gnwmtx'
# '87mebub9p4'

# %%
sessions.loc[sessions.id == '87mebub9p4']
# Out:
# Empty DataFrame
# Columns: [id, action, action_type, action_detail, device_type, secs_elapsed]
# Index: []
