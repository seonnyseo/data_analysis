# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
from collections import defaultdict

# %%
from tqdm import tqdm

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.write_html('first_figure.html', auto_open=True)

# %% [markdown]
# Data Load & Preprocess

# %%
df_train = pd.read_csv('../data/train_users.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
df_train.gender.value_counts()
# Out:
# -unknown-    95688
# FEMALE       63041
# MALE         54440
# OTHER          282
# Name: gender, dtype: int64

# %%
df_test = pd.read_csv('../data/test_users.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62096 entries, 0 to 62095
# Data columns (total 15 columns):
# id                         62096 non-null object
# date_account_created       62096 non-null object
# timestamp_first_active     62096 non-null int64
# date_first_booking         0 non-null float64
# gender                     62096 non-null object
# age                        33220 non-null float64
# signup_method              62096 non-null object
# signup_flow                62096 non-null int64
# language                   62096 non-null object
# affiliate_channel          62096 non-null object
# affiliate_provider         62096 non-null object
# first_affiliate_tracked    62076 non-null object
# signup_app                 62096 non-null object
# first_device_type          62096 non-null object
# first_browser              62096 non-null object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 7.1+ MB

# %%
remove_columns = ['date_first_booking', 'country_destination']
# ignore_index
users = pd.concat([df_train.loc[:, ~df_train.columns.isin(remove_columns)], df_test.loc[:,~df_test.columns.isin(remove_columns)]], ignore_index = True)

# %%
df_train['booked'] = df_train.date_first_booking.notnull()

# %% [markdown]
# Age

# %%
y = users.age.dropna().value_counts()
x = y.index

# %%
plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.grid(alpha = 0.5)
plt.xticks(rotation = 90)
plt.yscale("log")
plt.ylabel('Number of Users (log scale)')
plt.xlabel('Age')
plt.savefig('./figure/raw_age.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# use of loc

# %%
len(df_train)
# Out:
# 213451

# %%
df_train.loc[(df_train.age > 1000), 'age'].describe()
# Out:
# count     779.000000
# mean     2011.097561
# std        14.718288
# min      1924.000000
# 25%      2014.000000
# 50%      2014.000000
# 75%      2014.000000
# max      2014.000000
# Name: age, dtype: float64

# %%
age_mask = users.age > 1000
users.loc[age_mask, 'age'] = 2015 - users.loc[age_mask, 'age']

users.loc[(users.age > 100) | (users.age < 18), 'age'] = -1
users.age.fillna(-1, inplace = True)

y = users.loc[users.age != -1, 'age'].value_counts()
x = y.index

plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.grid(alpha = 0.3)
plt.xticks([age for age in range(20,101,10)])
plt.title('Airbnb Users Age Distribution')
plt.ylabel('Number of Users')
plt.xlabel('Age')
plt.savefig('./figure/age.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# DatetimeIndex

# %%
#df_train['date_account_created'] = pd.to_datetime(date_account_created, format='%Y-%m-%d', errors='ignore')
users['account_created_year'] = pd.DatetimeIndex(users['date_account_created']).year
users['account_created_month'] = pd.DatetimeIndex(users['date_account_created']).month
users['account_created_day'] = pd.DatetimeIndex(users['date_account_created']).day

# %% [markdown]
# User Acquisition

# %%
y = users.groupby('account_created_year').size()
x = y.index

plt.figure(figsize=(16,4))
plt.bar(x, y)
plt.grid(alpha = 0.2)
plt.show()

# %% [markdown]
# df.groupby().size()

# %%
year_month = users.groupby(['account_created_year', 'account_created_month']).size()

# %%
pd.crosstab(users.account_created_year, users.account_created_month)
# Out:
# account_created_month     1     2      3      4      5      6      7      8   \
# account_created_year
# 2010                      61   102    163    157    227    222    307    312
# 2011                     316   362    491    577    744    822    993   1454
# 2012                    1589  1789   2192   2589   3325   3867   4582   4476
# 2013                    4418  4362   5421   5855   6721   6765   7950   8369
# 2014                   11111  9967  12058  12689  14895  15746  21696  21626
#
# account_created_month     9     10    11    12
# account_created_year
# 2010                     371   309   286   271
# 2011                    1864  1477  1386  1289
# 2012                    4035  3828  3706  3484
# 2013                    9125  7862  7751  8361
# 2014                   18774     0     0     0

# %% [markdown]
# defaultdict(lambda :) -> lambda 작성하는 법

# %%
from collections import defaultdict

# %%
account_year_month = defaultdict(lambda: [-1 for x in range(13)])
for idx, val in zip(year_month.index, year_month):
    year = idx[0]
    month = idx[1]
    account_year_month[year][month] = val

# %%
fig, axes = plt.subplots(len(account_year_month.keys()), 1)

for year, ax in zip(account_year_month.keys(), axes):
    
    vals = account_year_month[year]
    start = next(x for x, val in enumerate(vals) if val != -1)
    end = next(x for x, val in enumerate(vals[::-1]) if val != -1)
    
    start = start if start != 0 else 1
    end = 13 - end if end != 0 else 13

    ax.plot([m for m in range(len(vals))], vals)
    ax.set_title(year, loc = 'left')

# %%
def draw_line_plot(data):
    plt.figure(figsize=(16,8))
    for year in data.keys():
        start = next(x for x, val in enumerate(data[year]) if val != -1)
        end = next(x for x, val in enumerate(data[year][::-1]) if val != -1)

        start = start if start != 0 else 1
        end = 13 - end if end != 0 else 13
        plt.plot([x for x in range(start, end)], data[year][start:end], label = year)
    
    plt.xticks([x for x in range(1, 13)])
    plt.legend()
    plt.grid(alpha = 0.3)
    
    plt.savefig('./figure/activation_month.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
draw_line_plot(account_year_month)

# %%
activation = pd.DataFrame(users.groupby(['account_created_year', 'account_created_month']).size())
activation = activation.rename(columns = {0:'number_of_users'})

# %%
plt.figure(figsize=(16, 5))  
x = ['{}-{:02}'.format(y, m) for (y, m) in activation.index]
y = activation['number_of_users']
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.grid(alpha = 0.5)
plt.title('The number of created account by Month')
plt.ylabel('Number of Created Account')
plt.savefig('./figure/activation.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Affiliate Channel

# %%
users.affiliate_channel.unique()
# Out:
# array(['direct', 'seo', 'other', 'sem-non-brand', 'content', 'sem-brand',
#        'remarketing', 'api'], dtype=object)

# %%
affi_channel_month = users.groupby(['account_created_year', 'account_created_month','affiliate_channel']).size().unstack()
affi_channel_month = affi_channel_month.fillna(0)

# %%
month_range = ['{}-{:02}'.format(y, m) for (y, m) in affi_channel_month.index]

# %%
channel_count = defaultdict(list)
for channel in affi_channel_month.columns:
    for m in range(len(affi_channel_month[channel])):
        count = affi_channel_month[channel][m]
        channel_count[channel].append(count)

# %%
users.columns
# Out:
# Index(['id', 'date_account_created', 'timestamp_first_active', 'gender', 'age',
#        'signup_method', 'signup_flow', 'language', 'affiliate_channel',
#        'affiliate_provider', 'first_affiliate_tracked', 'signup_app',
#        'first_device_type', 'first_browser', 'account_created_year',
#        'account_created_month', 'account_created_day'],
#       dtype='object')

# %%
pd.crosstab(users.account_created_year, users.account_created_month)
# Out:
# account_created_month     1     2      3      4      5      6      7      8   \
# account_created_year
# 2010                      61   102    163    157    227    222    307    312
# 2011                     316   362    491    577    744    822    993   1454
# 2012                    1589  1789   2192   2589   3325   3867   4582   4476
# 2013                    4418  4362   5421   5855   6721   6765   7950   8369
# 2014                   11111  9967  12058  12689  14895  15746  21696  21626
#
# account_created_month     9     10    11    12
# account_created_year
# 2010                     371   309   286   271
# 2011                    1864  1477  1386  1289
# 2012                    4035  3828  3706  3484
# 2013                    9125  7862  7751  8361
# 2014                   18774     0     0     0

# %%
plt.figure(figsize=(16,8))
for channel in channel_count.keys():
    plt.plot(month_range, channel_count[channel], label = channel)
plt.xticks(rotation = 90)
plt.legend(framealpha=1, frameon=True);
plt.grid(alpha=0.5)
plt.title('New inflow by channel')
plt.ylabel('Number of New Account')
plt.savefig('./figure/channel.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
count_by_month = pd.DataFrame.from_dict(channel_count, orient = 'index', columns = month_range)

# %%
add = pd.DataFrame([])
for idx in range(1, len(month_range)):
    previous = month_range[idx - 1]
    current = month_range[idx]
    add = pd.concat([add, pd.DataFrame(count_by_month[current] / count_by_month[previous], columns = [current])], axis = 1)

# %%
def color_negative_red(value):
    """
    Colors elements in a dateframe
    green if positive and red if
    negative. Does not color NaN
    values.
    """
    
    if value == 0:
        color = 'black'
    elif value >= 1:
        color = 'red'
    else:
        color = 'blue'
    return 'color: %s'%color

# %%
add.replace(np.inf, np.nan).round(2).fillna(0).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_435cb314_9094_11ea_ab7e_acde48001122row0_col0 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col1 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col2 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col3 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col4 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col5 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col6 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col7 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col8 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col9 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col10 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col11 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col12 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col13 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col14 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col15 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col16 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col17 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col18 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col19 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col20 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col21 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col22 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col23 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col24 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col25 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col26 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col27 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col28 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col29 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col30 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col31 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col32 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col33 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col34 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col35 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col36 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col37 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col38 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col39 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col40 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col41 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col42 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col43 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col44 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col45 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col46 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col47 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col48 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col49 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col50 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col51 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col52 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col53 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col54 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row0_col55 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col0 {
#             color:  black;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col1 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col2 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col3 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col4 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col5 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col6 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col7 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col8 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col9 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col10 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col11 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col12 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col13 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col14 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col15 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col16 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col17 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col18 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col19 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col20 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col21 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col22 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col23 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col24 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col25 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col26 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col27 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col28 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col29 {
#             color:  red;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col30 {
#             color:  blue;
#         }    #T_435cb314_9094_11ea_ab7e_acde48001122row1_col31 {
#             color:  red;

# %%
users.first_device_type.value_counts(normalize = True)
# Out:
# Mac Desktop           0.385880
# Windows Desktop       0.315547
# iPhone                0.144491
# iPad                  0.065455
# Other/Unknown         0.040527
# Android Phone         0.034324
# Android Tablet        0.007614
# Desktop (Other)       0.005469
# SmartPhone (Other)    0.000693
# Name: first_device_type, dtype: float64

# %%
_year = users.account_created_year
_month = users.account_created_month

by_year = pd.crosstab(_year, users.first_device_type).T.sort_values(by = 2014, ascending = False).T

x = by_year.index
plt.figure(figsize=(16,9))
for device in by_year.columns:
    y = by_year[device]
    plt.plot(x, y, label = device)

plt.legend()
plt.xticks(x)
plt.grid(alpha = 0.3)
plt.title('First Access by Device')
plt.savefig('./figure/first_device_year.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
group_columns = ['account_created_year', 'account_created_month', 'first_device_type']
year_month_device = users.loc[:,group_columns].groupby(group_columns).agg(len).unstack().fillna(0)
by_year_month = year_month_device.T.sort_values(by = (2014, 9), ascending = False).T

plt.figure(figsize=(16,9))
x = ['{}-{:02}'.format(y, m) for (y, m) in by_year_month.index]
for device in by_year_month.columns:
    y = by_year_month[device]
    plt.plot(x, y, label = device)

plt.legend()
plt.xticks(x, rotation = 90)
plt.grid(alpha = 0.3)
plt.savefig('./figure/device_by_month.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
mobile = ['iPhone', 'Android Phone', 'iPad', 'Android Tablet', 'SmartPhone (Other)']
desktop = ['Mac Desktop', 'Windows Desktop', 'Desktop (Other)']

mobile_mask = users.loc[users.first_device_type != 'Other/Unknown','first_device_type'].isin(mobile)
mobile_desktop = pd.crosstab(mobile_mask, [users.account_created_year, users.account_created_month])
mobile_desktop = mobile_desktop.sort_values(by = (2014, 9), ascending = False)

x = ['{}-{:02}'.format(y, m) for (y, m) in mobile_desktop.columns]
_desktop = mobile_desktop.T[False]
_mobile = mobile_desktop.T[True]

plt.figure(figsize = (16, 8))
plt.plot(x, _desktop, label = 'Desktop')
plt.plot(x, _mobile, label = 'Mobile')
plt.xticks(rotation = 90)
plt.grid(alpha = 0.3)
plt.legend()
plt.title('Mobile & Desktop Trace')
plt.savefig('./figure/mobile_desktop.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
_browser = ['Chrome', 'Safari', '-unknown-', 'Firefox', 'Mobile Safari', 'IE', 'Chrome Mobile', 'Android Browser']
browser_mask = users.first_browser.isin(_browser)

# %%
by_browser = pd.crosstab(users.loc[browser_mask, 'first_browser'], [users.account_created_year, users.account_created_month])
by_browser = by_browser.sort_values(by = (2014, 9), ascending = False)

# %%
plt.figure(figsize = (16, 8))
x = ['{}-{}'.format(y, m) for (y, m) in by_browser.columns]
for browser in by_browser.T.columns:
    plt.plot(x, by_browser.T[browser], label = browser)
plt.legend()
plt.grid(alpha = 0.3)
plt.xticks(rotation = 90)
plt.savefig('./figure/web_browser.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Session Data

# %%
sessions = pd.read_csv('../data/sessions.csv')

# %%
sessions = sessions.rename(columns = {'user_id':'id'})

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# id               object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
sessions.isna().sum()
# Out:
# id                 34496
# action             79626
# action_type      1126204
# action_detail    1126204
# device_type            0
# secs_elapsed      136031
# dtype: int64

# %%
# remove rows NaN id
sessions = sessions.dropna(subset = ['id'])

# %%
len(sessions)
# Out:
# 10533241

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
sessions['secs_elapsed'] = sessions['secs_elapsed'].fillna(0)

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
len(sessions)
# Out:
# 10533241

# %%
sessions_ids = sessions.id.unique()

# %%
from_train = df_train.loc[df_train.id.isin(sessions_ids), ['id', 'date_account_created']]
from_test = df_test.loc[df_test.id.isin(sessions_ids), ['id', 'date_account_created']]
account_created_date = pd.concat([from_train, from_test], axis = 0)

# %%
sessions['cumulate_secs'] = sessions.groupby('id')['secs_elapsed'].cumsum()
sessions['cumulate_days'] = sessions['cumulate_secs']/60/60//24

# %%
from tqdm import tqdm

# %% [markdown]
# pd.DatetimeIndex -> list를 받음
#
# pd.to_datetime
#
# 여기 차이 알고하는게 좋을 듯 (속도에 영향을 끼침)

# %%
account_date = defaultdict()
for _id, _date in zip(account_created_date['id'], account_created_date['date_account_created']):
    account_date[_id] = pd.to_datetime(_date)

# %% [markdown]
# account_date dictionary -> much faster

# %%
from tqdm import tqdm

# %%
def return_session_date(row):
    _id = row['id']
    _delta = row['cumulate_days']
    
    return account_date[_id] + pd.DateOffset(_delta)

tqdm.pandas()
sessions['session_date'] = sessions.loc[:, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)
# Out:
# /Users/keonhoseo/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#
# 100%|██████████| 10533241/10533241 [08:24<00:00, 20886.89it/s]

# %%
"""
def return_session_date(row):
    _id = row['id']
    _delta = row['cumulate_days']
    
    _date = pd.DatetimeIndex(account_created_date[account_created_date.id == _id]['date_account_created'])
    _date += pd.DateOffset(_delta)
    
    return _date.date

#from tqdm import tqdm_notebook as tqdm
tqdm.pandas()
sessions['session_date'] = sessions.loc[:4, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)
"""
# Out:
# "\ndef return_session_date(row):\n    _id = row['id']\n    _delta = row['cumulate_days']\n    \n    _date = pd.DatetimeIndex(account_created_date[account_created_date.id == _id]['date_account_created'])\n    _date += pd.DateOffset(_delta)\n    \n    return _date.date\n\n#from tqdm import tqdm_notebook as tqdm\ntqdm.pandas()\nsessions['session_date'] = sessions.loc[:4, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)\n"

# %%
sessions.head(5)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed  cumulate_secs  cumulate_days session_date
# 0  Windows Desktop         319.0          319.0            0.0   2014-01-01
# 1  Windows Desktop       67753.0        68072.0            0.0   2014-01-01
# 2  Windows Desktop         301.0        68373.0            0.0   2014-01-01
# 3  Windows Desktop       22141.0        90514.0            1.0   2014-01-02
# 4  Windows Desktop         435.0        90949.0            1.0   2014-01-02

# %%
booked_users_id = df_train.loc[pd.notnull(df_train.date_first_booking), 'id']

# %%
booked_users = sessions.loc[sessions.id.isin(booked_users_id)]
unbooked_users = sessions.loc[~sessions.id.isin(booked_users_id)]

# %%
mask = df_train.date_account_created > df_train.date_first_booking
book_first = df_train.loc[(df_train.id.isin(booked_users_id)) & mask].id
sessions.loc[sessions.id.isin(book_first)]
# Out:
# Empty DataFrame
# Columns: [id, action, action_type, action_detail, device_type, secs_elapsed, cumulate_secs, cumulate_days, session_date]
# Index: []

# %%
len(book_first)
# Out:
# 29

# %%
sessions.cumulate_days.quantile([.15, .2, .5, .8, .99])
# Out:
# 0.15      1.0
# 0.20      2.0
# 0.50     11.0
# 0.80     32.0
# 0.99    122.0
# Name: cumulate_days, dtype: float64

# %% [markdown]
# bringing cumulate_days up is required

# %%
_retention = []
_retention_days = sessions.groupby('id')['cumulate_days'].agg(['max'])
for day in range(0, 121):
    _retention.append(1 - ((_retention_days < day).sum() / len(_retention_days)))

# %%
plt.figure(figsize=(16,8))
plt.plot(range(0, 121), _retention)
#plt.legend()
plt.xticks(range(0,121, 5))
plt.grid(alpha = 0.5)
plt.savefig('./figure/retention.png', dpi=300, bbox_inches='tight')
plt.ylabel('Percentage')
plt.xlabel('Retention period After Signup')
plt.title('User Retention Rate')
plt.show()

# %%
booked_users_elapsed = booked_users.groupby('id')['secs_elapsed'].agg(['sum', ('day', lambda x: np.sum(x)/60/60/24)])
unbooked_users_elapsed = unbooked_users.groupby('id')['secs_elapsed'].agg(['sum', ('day', lambda x: np.sum(x)/60/60/24)])

# %%
_booked = []
_unbooked = []
for day in range(0, 121):
    _booked.append(1 - (len(booked_users_elapsed.loc[booked_users_elapsed.day < day]) / len(booked_users_elapsed)))
    _unbooked.append(1 - (len(unbooked_users_elapsed.loc[unbooked_users_elapsed.day < day]) / len(unbooked_users_elapsed)))

# %%
plt.figure(figsize=(16,8))
plt.plot(range(0, 121), _booked, label = 'Booked Users')
plt.plot(range(0, 121), _unbooked, label = 'Unbooked Users')
plt.legend()
plt.xticks(range(0,121, 5))
plt.grid(alpha = 0.5)
plt.savefig('./figure/retention_by_booking.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
retention = pd.concat([booked_users_elapsed, unbooked_users_elapsed])

# %%
bottom_20 = retention.loc[retention.day <= 2].index
top_20 = retention.loc[retention.day >= 32].index

# %%
print(len(bottom_20))
print(len(top_20))
# Out:
# 26342
# 21965

# %%
b_20 = sessions.loc[sessions.id.isin(bottom_20)].groupby(['id','action'])['action_type'].agg('count')
b_20_actions = defaultdict(int)
for idx, count in zip(b_20.index, b_20):
    b_20_actions[idx[1]] += count

# %%
t_20 = sessions.loc[sessions.id.isin(top_20)].groupby(['id','action'])['action_type'].agg('count')
t_20_actions = defaultdict(int)
for idx, count in zip(t_20.index, t_20):
    t_20_actions[idx[1]] += count

# %%
sum(b_20_actions.values())
# Out:
# 225236

# %%
sum(t_20_actions.values())
# Out:
# 4280017

# %%
total = sum(b_20_actions.values())
for (k, v) in sorted(b_20_actions.items(), key = lambda k_v:k_v[1], reverse = True):
    print(k, round(v / total, 7))
# Out:
# show 0.1643121
# header_userpic 0.0822204
# active 0.0682795
# index 0.0612957
# create 0.0596574
# dashboard 0.0533352
# personalize 0.0493038
# search 0.0481939
# update 0.037676
# search_results 0.0304125
# authenticate 0.0281083
# notifications 0.0269584
# ajax_refresh_subtotal 0.0247429
# reviews 0.0224875
# social_connections 0.0184473
# collections 0.0172974
# ask_question 0.0168357
# confirm_email 0.0162807
# similar_listings 0.0161253
# callback 0.0110551
# unavailabilities 0.0093413
# edit 0.0087997
# impressions 0.0076631
# manage_listing 0.0060426
# listings 0.0047728
# travel_plans_current 0.0046174
# recommended_listings 0.0039736
# custom_recommended_destinations 0.0038759
# show_personalize 0.0038493
# identity 0.0037294
# cancellation_policies 0.0036184
# payment_instruments 0.0035918
# signup_login 0.0034275
# populate_help_dropdown 0.0033831
# set_user 0.0033742
# ajax_check_dates 0.0033476
# payment_methods 0.0031833
# click 0.0026683
# open_graph_setting 0.002615
# login 0.0025884
# settings 0.0025351
# qt2 0.0025307
# new 0.0024818
# edit_verification 0.0023531
# account 0.0022998
# ajax_get_referrals_amt 0.0022066
# ajax_lwlb_contact 0.0019713
# tos_confirm 0.0016161
# recommendations 0.001545
# other_hosting_reviews_first 0.001545
# available 0.0015362
# hosting_social_proof 0.0014074
# facebook_auto_login 0.0013186
# calendar_tab_inner2 0.0012787
# requested 0.0011632
# ajax_referral_banner_experiment_type 0.0009723
# referrer_status 0.0009679
# reviews_new 0.0009679
# ajax_referral_banner_type 0.0008702
# faq 0.0008702
# my 0.0008613
# read_policy_click 0.0008214
# cancellation_policy_click 0.0007903
# pending 0.0007636
# references 0.0007326
# set_password 0.0007326
# tell_a_friend 0.0007192
# message_to_host_focus 0.0007104
# faq_category 0.0006704
# view 0.000626
# login_modal 0.0005905
# signup_modal 0.000555
# jumio_token 0.000555
# payout_preferences 0.0005461
# travel_plans_previous 0.0005372
# verify 0.0005283
# apply_code 0.0005061
# decision_tree 0.0004751
# connect 0.0004529
# create_multiple 0.0004351
# recent_reservations 0.0004351
# transaction_history 0.0004085
# multi 0.0003996
# apply_reservation 0.0003951
# agree_terms_check 0.0003907
# ajax_statsd 0.0003774
# itinerary 0.0003774
# phone_number_widget 0.0003685
# domains 0.0003507
# contact_new 0.0003197
# pending_tickets 0.0003197
# populate_from_facebook 0.000293
# faq_experiment_ids 0.0002886
# message_to_host_change 0.0002841
# privacy 0.0002708
# transaction_history_paginated 0.0002708
# kba 0.0002575
# coupon_code_click 0.0002486
# ajax_photo_widget_form_iframe 0.0002397
# top_destinations 0.0002309
# kba_update 0.000222
# popular 0.0002175
# glob 0.0002131
# update_notifications 0.0002131
# terms 0.0002087
# friends 0.0001954
# position 0.0001909
# coupon_field_focus 0.0001865
# profile_pic 0.0001776
# reputation 0.0001776
# authorize 0.0001732
# host_summary 0.0001687
# issue 0.0001687
# apply_coupon_click 0.0001687
# ajax_image_upload 0.0001643
# handle_vanity_url 0.0001598
# how_it_works 0.0001554
# apply_coupon_error 0.0001554
# campaigns 0.000151
# my_listings 0.0001465
# apply_coupon_error_type 0.0001465
# supported 0.0001421
# remove_dashboard_alert 0.0001332
# spoken_languages 0.0001332
# show_code 0.0001288
# forgot_password 0.0001243
# this_hosting_reviews 0.0001243
# my_reservations 0.0001199
# request_new_confirm_email 9.77e-05
# mobile_landing_page 9.32e-05
# delete 8.44e-05
# at_checkpoint 8.44e-05
# signup_weibo_referral 7.99e-05
# languages_multiselect 7.55e-05
# terms_and_conditions 7.1e-05
# photography 6.66e-05
# why_host 6.66e-05
# salute 6.66e-05
# trust 6.22e-05
# change_currency 5.33e-05
# patch 5.33e-05
# submit_contact 5.33e-05
# requirements 5.33e-05
# airbnb_picks 5.33e-05
# recommend 4.44e-05
# update_hide_from_search_engines 4.44e-05
# qt_with 4.44e-05
# p4_refund_policy_terms 4.44e-05
# update_friends_display 4e-05
# qt_reply_v2 4e-05
# weibo_signup_referral_finish 4e-05
# department 3.55e-05
# rate 3.11e-05
# about_us 3.11e-05
# create_airbnb 2.66e-05
# this_hosting_reviews_3000 2.66e-05
# review_page 2.66e-05
# endpoint_error 2.66e-05
# p4_terms 2.66e-05
# pay 2.66e-05
# listing 2.66e-05
# ajax_google_translate_description 2.22e-05
# guarantee 2.22e-05
# countries 2.22e-05
# departments 2.22e-05
# signature 2.22e-05
# other_hosting_reviews 1.78e-05
# change_password 1.78e-05
# press_news 1.78e-05
# phone_verification_number_submitted_for_sms 1.78e-05
# phone_verification_number_sucessfully_submitted 1.78e-05
# home_safety_landing 1.78e-05
# questions 1.33e-05
# ajax_google_translate_reviews 1.33e-05
# media_resources 1.33e-05
# zendesk_login_jwt 1.33e-05
# phone_verification_success 1.33e-05
# hospitality 1.33e-05
# detect_fb_session 1.33e-05
# complete_status 1.33e-05
# complete 1.33e-05
# destroy 1.33e-05
# jumio_redirect 8.9e-06
# clickthrough 8.9e-06
# home_safety_terms 8.9e-06
# host_2013 8.9e-06
# localized 8.9e-06
# redirect 8.9e-06
# apply 8.9e-06
# email_wishlist 8.9e-06
# feed 8.9e-06
# ajax_payout_options_by_country 8.9e-06
# apply_coupon_click_success 8.9e-06
# confirmation 8.9e-06
# united-states 8.9e-06
# 10 4.4e-06
# toggle_archived_thread 4.4e-06
# ajax_google_translate 4.4e-06
# locations 4.4e-06
# office_location 4.4e-06
# agree_terms_uncheck 4.4e-06
# life 4.4e-06
# place_worth 4.4e-06
# invalid_action 4.4e-06
# complete_redirect 4.4e-06
# hospitality_standards 4.4e-06
# email_share 4.4e-06
# overview 4.4e-06
# sldf 4.4e-06
# 11 4.4e-06
# country_options 4.4e-06
# toggle_starred_thread 4.4e-06
# receipt 4.4e-06
# clear_reservation 4.4e-06
# social 4.4e-06
# friends_new 4.4e-06
# wishlists 4.4e-06
# sublets 4.4e-06
# press_release 4.4e-06
# concierge 4.4e-06
# similar_listings_v2 0.0
# localization_settings 0.0
# currencies 0.0
# lookup 0.0
# track_page_view 0.0
# signed_out_modal 0.0

# %%
sessions.loc[sessions.action == 'similar_listings', 'action_detail'].value_counts()
# Out:
# similar_listings    363423
# Name: action_detail, dtype: int64

# %%
total = sum(t_20_actions.values())
for (k, v) in sorted(t_20_actions.items(), key = lambda k_v:k_v[1], reverse = True):
    print(k, round(v / total, 7))
# Out:
# show 0.2338091
# index 0.1008804
# personalize 0.085812
# search_results 0.0851616
# ajax_refresh_subtotal 0.0600192
# similar_listings 0.0463293
# search 0.0459251
# update 0.0406625
# social_connections 0.0332735
# reviews 0.0294249
# active 0.015127
# edit 0.0119046
# collections 0.0117411
# dashboard 0.0115102
# create 0.0109759
# qt2 0.0104259
# header_userpic 0.0082184
# unavailabilities 0.007467
# ajax_check_dates 0.0060976
# show_personalize 0.0060677
# calendar_tab_inner2 0.0059301
# identity 0.0058325
# listings 0.0056577
# notifications 0.0045362
# requested 0.0041526
# ajax_lwlb_contact 0.003924
# ask_question 0.003917
# other_hosting_reviews_first 0.0038834
# travel_plans_current 0.0038649
# edit_verification 0.0038203
# confirm_email 0.0037792
# complete_status 0.0034757
# manage_listing 0.0031269
# recommendations 0.0029339
# ajax_photo_widget_form_iframe 0.002932
# authenticate 0.002686
# click 0.0025491
# payment_instruments 0.0023217
# impressions 0.0021946
# payment_methods 0.0020488
# verify 0.0019177
# message_to_host_focus 0.0018787
# profile_pic 0.0018152
# cancellation_policies 0.0016906
# custom_recommended_destinations 0.0016028
# populate_help_dropdown 0.0015598
# my 0.0014888
# ajax_image_upload 0.001486
# qt_reply_v2 0.0014738
# settings 0.0014486
# callback 0.0013477
# kba_update 0.0013292
# references 0.0013255
# pending 0.0013154
# view 0.0012416
# message_to_host_change 0.0011755
# ajax_get_referrals_amt 0.0011231
# connect 0.0010958
# faq 0.0010748
# new 0.001036
# apply_reservation 0.0010353
# populate_from_facebook 0.0009696
# jumio_token 0.000964
# handle_vanity_url 0.0009175
# agree_terms_check 0.0009168
# account 0.0008993
# recommended_listings 0.0008773
# kba 0.0008385
# request_new_confirm_email 0.0008231
# coupon_field_focus 0.0007909
# phone_number_widget 0.0007166
# faq_category 0.0007042
# status 0.0006834
# available 0.0006717
# push_notification_callback 0.0006456
# delete 0.000643
# apply_coupon_click 0.0006407
# payout_preferences 0.0006343
# reviews_new 0.0006229
# languages_multiselect 0.0005993
# apply_coupon_error 0.0005895
# 10 0.0005883
# jumio_redirect 0.0005876
# apply_coupon_error_type 0.0005876
# this_hosting_reviews 0.0005402
# at_checkpoint 0.0005019
# complete_redirect 0.0004956
# ajax_referral_banner_experiment_type 0.0004743
# open_graph_setting 0.0004734
# set_user 0.0004729
# ajax_referral_banner_type 0.0004631
# endpoint_error 0.0004577
# signup_login 0.0004175
# hosting_social_proof 0.0003963
# 12 0.0003731
# facebook_auto_login 0.0003685
# decision_tree 0.000357
# host_summary 0.0003523
# recent_reservations 0.0003276
# referrer_status 0.0003175
# read_policy_click 0.0002946
# pay 0.0002808
# signature 0.000275
# phone_verification_number_submitted_for_sms 0.0002748
# login 0.0002729
# tell_a_friend 0.0002703
# coupon_code_click 0.0002612
# itinerary 0.00026
# contact_new 0.0002556
# cancellation_policy_click 0.0002556
# qt_with 0.0002414
# ajax_statsd 0.0002393
# privacy 0.0002318
# transaction_history 0.0002318
# phone_verification_number_sucessfully_submitted 0.0002276
# popular 0.0002133
# phone_verification_modal 0.0002033
# 15 0.0002
# this_hosting_reviews_3000 0.0001925
# change 0.0001918
# add_note 0.0001883
# phone_verification_success 0.000179
# update_cached 0.0001769
# complete 0.0001717
# patch 0.0001703
# supported 0.0001673
# update_notifications 0.0001549
# tos_confirm 0.0001542
# login_modal 0.0001537
# terms 0.0001533
# create_multiple 0.0001521
# spoken_languages 0.0001512
# pending_tickets 0.0001474
# ajax_google_translate_reviews 0.0001418
# signup_modal 0.0001378
# glob 0.0001315
# ajax_payout_edit 0.0001304
# set_password 0.0001294
# top_destinations 0.0001269
# authorize 0.0001257
# ajax_google_translate_description 0.0001236
# transaction_history_paginated 0.0001213
# ajax_payout_options_by_country 0.0001203
# upload 0.0001138
# domains 0.0001129
# 11 0.0001077
# phone_verification_error 0.0001044
# other_hosting_reviews 0.0001035
# requirements 0.0001012
# issue 9.93e-05
# faq_experiment_ids 9.65e-05
# photography 9.63e-05
# my_listings 9.6e-05
# review_page 9.21e-05
# cancel 9.09e-05
# trust 8.9e-05
# webcam_upload 8.64e-05
# payout_update 8.41e-05
# listing 8.27e-05
# phone_verification_number_submitted_for_call 7.64e-05
# receipt 7.62e-05
# toggle_archived_thread 7.13e-05
# remove_dashboard_alert 6.99e-05
# forgot_password 6.99e-05
# friends_new 6.92e-05
# image_order 6.89e-05
# friends 6.73e-05
# mobile_oauth_callback 6.57e-05
# overview 6.47e-05
# my_reservations 6.19e-05
# rate 6.1e-05
# mobile_landing_page 5.89e-05
# change_currency 5.7e-05
# how_it_works 5.7e-05
# agree_terms_uncheck 5.65e-05
# ajax_get_results 5.65e-05
# ajax_google_translate 5.19e-05
# travel_plans_previous 4.95e-05
# guest_booked_elsewhere 4.6e-05
# apply_code 4.56e-05
# email_wishlist 4.49e-05
# position 4.46e-05
# jumio 4.09e-05
# become_user 3.69e-05
# email_share 3.62e-05
# toggle_starred_thread 3.62e-05
# about_us 3.57e-05
# relationship 3.25e-05
# ajax_price_and_availability 3.08e-05
# p4_refund_policy_terms 2.8e-05
# book 2.78e-05
# clickthrough 2.69e-05
# destroy 2.66e-05
# terms_and_conditions 2.64e-05
# apply_coupon_click_success 2.62e-05
# campaigns 2.59e-05
# airbnb_picks 2.57e-05
# department 2.57e-05
# update_hide_from_search_engines 2.41e-05
# country_options 2.38e-05
# submit_contact 2.36e-05
# countries 2.34e-05
# guarantee 2.27e-05
# phone_verification_phone_number_removed 2.22e-05
# multi 2.17e-05
# salute 2.1e-05
# phone_verification_call_taking_too_long 2.08e-05
# p4_terms 2.03e-05
# email_itinerary_colorbox 1.94e-05
# change_password 1.87e-05
# update_friends_display 1.73e-05
# home_safety_landing 1.71e-05
# departments 1.59e-05
# show_code 1.52e-05
# invalid_action 1.45e-05
# popular_listing 1.43e-05
# why_host 1.38e-05
# office_location 1.38e-05
# request_photography 1.14e-05
# clear_reservation 1.1e-05
# update_reservation_requirements 1.05e-05
# payoneer_account_redirect 9.8e-06
# recommend 9.8e-06
# hospitality 9.1e-06
# print_confirmation 8.9e-06
# create_airbnb 8.9e-06
# add_guests 8.2e-06
# reservation 8.2e-06
# guest_billing_receipt 8.2e-06
# change_availability 8.2e-06
# new_session 7.9e-06
# multi_message 7.7e-06
# create_ach 7.5e-06
# create_paypal 7.5e-06
# update_country_of_residence 7e-06
# place_worth 6.1e-06
# acculynk_session_obtained 5.8e-06
# unread 5.6e-06
# locations 5.6e-06
# press_release 5.6e-06
# social 5.6e-06
# multi_message_attributes 5.6e-06
# acculynk_bin_check_success 5.6e-06
# acculynk_load_pin_pad 5.4e-06
# founders 4.9e-06
# press_news 4.9e-06
# united-states 4.9e-06
# slideshow 4.9e-06
# support_phone_numbers 4.7e-06
# hospitality_standards 4.7e-06
# payoneer_signup_complete 4.7e-06
# ajax_worth 4.4e-06
# signup_weibo_referral 4.4e-06
# zendesk_login_jwt 4.2e-06
# home_safety_terms 4e-06
# concierge 3.5e-06
# has_profile_pic 3.3e-06
# badge 3.3e-06
# detect_fb_session 3e-06
# host_2013 3e-06
# sublets 3e-06
# google_importer 2.8e-06
# weibo_signup_referral_finish 2.6e-06
# ajax_send_message 2.6e-06
# load_more 2.6e-06
# acculynk_pin_pad_inactive 2.3e-06
# views 2.1e-06
# life 2.1e-06
# respond 2.1e-06
# approve 2.1e-06
# email_by_key 1.9e-06
# set_default 1.9e-06
# localization_settings 1.6e-06
# press_content 1.6e-06
# localized 1.6e-06
# ajax_payout_split_edit 1.6e-06
# change_default_payout 1.6e-06
# business_travel 1.6e-06
# media_resources 1.4e-06
# onenight 1.4e-06
# maybe_information 1.4e-06
# add_guest_colorbox 1.4e-06
# pricing 1.4e-06
# city_count 1.4e-06
# feed 1.4e-06
# social-media 1.2e-06
# redirect 1.2e-06
# rentals 1.2e-06
# acculynk_pin_pad_success 1.2e-06
# add_business_address_colorbox 9e-07
# photography_update 7e-07
# sync 7e-07
# envoy_form 7e-07
# locale_from_host 7e-07
# ajax_photo_widget 7e-07
# toggle_availability 7e-07
# payout_delete 7e-07
# airbrb 7e-07
# booking 7e-07
# preapproval 5e-07
# acculynk_pin_pad_error 5e-07
# stpcv 5e-07
# ajax_ldp 5e-07
# envoy_bank_details_redirect 5e-07
# ajax_special_offer_dates_available 5e-07
# views_campaign 5e-07
# sandy 5e-07
# accept_decline 5e-07
# refund_guest_cancellation 5e-07
# reputation 5e-07
# special_offer 5e-07
# host_cancel 2e-07
# currencies 2e-07
# recommendation_page 2e-07
# hard_fallback_submit 2e-07
# open_hard_fallback_modal 2e-07
# revert_to_admin 2e-07
# set_minimum_payout_amount 2e-07
# acculynk_bin_check_failed 2e-07
# reset_calendar 2e-07
# message 2e-07
# desks 2e-07
# deauthorize 2e-07
# travel 2e-07
# events 2e-07
# lookup 0.0
# similar_listings_v2 0.0
# track_page_view 0.0
# signed_out_modal 0.0
# uptodate 0.0
# check 0.0
# braintree_client_token 0.0
# phone_verification 0.0
# widget 0.0
# satisfy 0.0
# track_activity 0.0

# %%
action_count = sessions.groupby(['id', 'action'])['action_type'].agg('count')

# %%
action_count.unstack().loc[action_count.unstack()['confirm_email'] > 1]['confirm_email'].mean()
# Out:
# 2.4192238267148016

# %%
action_count.unstack().loc[action_count.unstack()['confirm_email'] > 1]['confirm_email'].max()
# Out:
# 18.0

# %% [markdown]
# MAU (Monthly Active Users)

# %%
daily_access = sessions.groupby(['id', 'session_date'])['action'].agg('nunique')

# %%
daily_access.reset_index()['session_date']
# Out:
# 0         2014-05-14
# 1         2014-05-15
# 2         2014-05-16
# 3         2014-05-23
# 4         2014-05-24
#              ...
# 1335185   2014-06-11
# 1335186   2014-06-12
# 1335187   2014-06-13
# 1335188   2014-06-14
# 1335189   2014-06-15
# Name: session_date, Length: 1335190, dtype: datetime64[ns]

# %% [markdown]
# DAU

# %%
dau = daily_access.reset_index()['session_date'].value_counts()

# %%
plt.figure(figsize=(16,7))
plt.bar(dau.index, dau)
plt.grid(alpha = 0.3)
plt.show()

# %%
_year = pd.DatetimeIndex(daily_access.reset_index()['session_date']).year
_month = pd.DatetimeIndex(daily_access.reset_index()['session_date']).month

# %%
y = pd.crosstab(_year, _month).stack()
x = ['{}-{:02}'.format(year, month) for (year, month) in y.index]

plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.grid(alpha = 0.2)
plt.show()

# %%
t = sessions.action.value_counts()
for idx, c in zip(t.index, t):
    print(idx, c)
# Out:
# show 2758985
# index 841071
# search_results 723124
# personalize 704782
# search 533833
# ajax_refresh_subtotal 486414
# similar_listings 363423
# update 362708
# social_connections 337764
# reviews 319318
# active 187370
# similar_listings_v2 168457
# lookup 161422
# create 155233
# dashboard 152515
# header_userpic 141315
# collections 124067
# edit 108927
# campaigns 104647
# track_page_view 80949
# unavailabilities 77985
# qt2 64585
# notifications 59198
# confirm_email 58557
# requested 57020
# identity 53550
# ajax_check_dates 52426
# show_personalize 50353
# ask_question 43972
# listings 43515
# authenticate 42841
# calendar_tab_inner2 41947
# travel_plans_current 38139
# edit_verification 33374
# ajax_lwlb_contact 33345
# other_hosting_reviews_first 30996
# recommendations 30497
# impressions 27746
# manage_listing 26267
# click 25456
# complete_status 24667
# ajax_photo_widget_form_iframe 24425
# payment_instruments 23461
# message_to_host_focus 21629
# verify 21324
# payment_methods 19736
# cancellation_policies 19220
# callback 19053
# settings 16740
# custom_recommended_destinations 16507
# pending 15987
# profile_pic 15794
# populate_help_dropdown 15259
# message_to_host_change 14219
# ajax_image_upload 13546
# view 13088
# kba_update 12681
# references 11385
# my 11286
# ajax_get_referrals_amt 11278
# new 10988
# agree_terms_check 10934
# apply_reservation 10911
# connect 10089
# recommended_listings 9982
# faq 9456
# populate_from_facebook 9179
# account 9004
# available 8674
# jumio_token 8667
# qt_reply_v2 8529
# signup_login 8384
# request_new_confirm_email 7932
# handle_vanity_url 7914
# kba 7909
# coupon_field_focus 7604
# phone_number_widget 7311
# open_graph_setting 7205
# set_user 6885
# faq_category 6564
# apply_coupon_click 6219
# reviews_new 5820
# apply_coupon_error 5563
# apply_coupon_error_type 5547
# languages_multiselect 5400
# localization_settings 5391
# at_checkpoint 5166
# jumio_redirect 5146
# delete 5021
# ajax_referral_banner_experiment_type 4912
# login 4801
# endpoint_error 4765
# payout_preferences 4541
# complete_redirect 4504
# status 4480
# ajax_referral_banner_type 4444
# hosting_social_proof 4344
# referrer_status 4250
# facebook_auto_login 3980
# read_policy_click 3900
# this_hosting_reviews 3859
# cancellation_policy_click 3455
# uptodate 3329
# push_notification_callback 3327
# tell_a_friend 3302
# 10 3202
# phone_verification_number_submitted_for_sms 2963
# coupon_code_click 2944
# tos_confirm 2935
# decision_tree 2726
# recent_reservations 2461
# phone_verification_number_sucessfully_submitted 2460
# pay 2292
# 12 2204
# popular 2151
# host_summary 2106
# create_multiple 2094
# phone_verification_success 2030
# transaction_history 2029
# login_modal 1973
# terms 1941
# privacy 1939
# ajax_statsd 1916
# itinerary 1870
# signup_modal 1830
# signature 1814
# qt_with 1793
# contact_new 1784
# patch 1577
# set_password 1568
# phone_verification_modal 1558
# domains 1528
# spoken_languages 1469
# this_hosting_reviews_3000 1375
# update_notifications 1315
# supported 1275
# top_destinations 1272
# pending_tickets 1263
# glob 1238
# complete 1130
# transaction_history_paginated 1130
# change 1116
# faq_experiment_ids 1085
# signed_out_modal 1054
# 15 1053
# phone_verification_error 1033
# authorize 1029
# position 974
# add_note 960
# ajax_google_translate_reviews 949
# ajax_google_translate_description 931
# issue 863
# update_cached 835
# webcam_upload 815
# remove_dashboard_alert 812
# apply_code 805
# friends 804
# listing 772
# upload 762
# forgot_password 755
# other_hosting_reviews 749
# how_it_works 747
# trust 739
# my_listings 730
# requirements 713
# ajax_payout_edit 711
# 11 702
# phone_verification_number_submitted_for_call 687
# ajax_payout_options_by_country 679
# travel_plans_previous 672
# photography 629
# mobile_landing_page 618
# change_currency 603
# agree_terms_uncheck 597
# cancel 581
# review_page 564
# my_reservations 553
# rate 505
# friends_new 476
# payout_update 467
# receipt 459
# mobile_oauth_callback 434
# image_order 418
# department 417
# about_us 412
# email_wishlist 388
# overview 381
# toggle_archived_thread 380
# recommend 375
# p4_refund_policy_terms 368
# ajax_get_results 367
# terms_and_conditions 329
# multi 328
# apply_coupon_click_success 328
# email_share 319
# jumio 319
# salute 317
# currencies 297
# p4_terms 292
# ajax_google_translate 290
# airbnb_picks 278
# show_code 259
# departments 246
# guarantee 246
# book 243
# submit_contact 241
# clickthrough 238
# update_hide_from_search_engines 226
# destroy 226
# guest_booked_elsewhere 221
# toggle_starred_thread 206
# phone_verification_phone_number_removed 206
# phone_verification_call_taking_too_long 192
# relationship 187
# countries 182
# become_user 180
# ajax_price_and_availability 175
# why_host 174
# change_password 172
# update_friends_display 171
# office_location 163
# country_options 155
# email_itinerary_colorbox 140
# invalid_action 139
# home_safety_landing 134
# braintree_client_token 120
# clear_reservation 119
# check 119
# place_worth 106
# popular_listing 93
# signup_weibo_referral 90
# create_airbnb 86
# hospitality 81
# locations 75
# widget 75
# new_session 69
# print_confirmation 69
# founders 62
# add_guests 60
# update_country_of_residence 59
# request_photography 59
# reputation 57
# ajax_worth 56
# social 55
# update_reservation_requirements 55
# press_release 54
# multi_message 52
# press_news 52
# acculynk_session_obtained 52
# multi_message_attributes 51
# acculynk_bin_check_success 51
# guest_billing_receipt 50
# acculynk_load_pin_pad 50
# detect_fb_session 49
# concierge 47
# create_paypal 47
# hospitality_standards 47
# change_availability 47
# payoneer_account_redirect 45
# weibo_signup_referral_finish 45
# slideshow 40
# unread 40
# create_ach 39
# reservation 38
# redirect 35
# badge 34
# sublets 31
# home_safety_terms 31
# acculynk_pin_pad_inactive 30
# united-states 30
# life 28
# host_2013 27
# zendesk_login_jwt 24
# views 22
# google_importer 22
# payoneer_signup_complete 21
# set_default 21
# ajax_send_message 21
# support_phone_numbers 20
# ajax_ldp 19
# has_profile_pic 18
# phone_verification 16
# onenight 15
# localized 15
# business_travel 14
# press_content 14
# load_more 13
# media_resources 12
# feed 11
# approve 11
# questions 11
# respond 11
# open_hard_fallback_modal 10
# signup_weibo 10
# change_default_payout 9
# satisfy 9
# add_business_address_colorbox 9
# envoy_form 8
# ajax_photo_widget 8
# city_count 8
# email_by_key 8
# ajax_payout_split_edit 7
# social-media 7
# add_guest_colorbox 7
# maybe_information 7
# pricing 7
# rentals 7
# photography_update 6
# new_host 6
# disaster_action 6
# track_activity 6
# sync 5
# travel 5
# apply 5
# acculynk_pin_pad_success 5
# payout_delete 5
# acculynk_pin_pad_error 4
# southern-europe 4
# locale_from_host 4
# hard_fallback_submit 4
# message 4
# booking 4
# ajax_special_offer_dates_available 3
# toggle_availability 3
# airbrb 3
# envoy_bank_details_redirect 2
# stpcv 2
# preapproval 2
# unsubscribe 2
# report 2
# use_mobile_site 2
# confirmation 2
# reset_calendar 2
# views_campaign_rules 2
# accept_decline 2
# rest-of-world 2
# recommendation_page 2
# refund_guest_cancellation 2
# sandy 2
# south-america 2
# friend_listing 2
# tos_2014 2
# views_campaign 2
# special_offer 2
# update_message 1
# reactivate 1
# deauthorize 1
# wishlists 1
# deactivated 1
# deactivate 1
# sldf 1
# host_cancel 1
# desks 1
# acculynk_bin_check_failed 1
# plaxo_cb 1
# set_minimum_payout_amount 1
# nyan 1
# revert_to_admin 1
# events 1

# %%
gender_destination = pd.crosstab(df_train.gender, df_train.country_destination, normalize = True)
gender_destination['SUM'] = gender_destination.agg(np.sum, axis = 1)
gender_destination.loc['SUM'] = gender_destination.sum()
gender_destination
# Out:
# country_destination        AU        CA        DE        ES        FR  \
# gender
# -unknown-            0.000670  0.002300  0.001331  0.003350  0.008025
# FEMALE               0.000970  0.002132  0.001677  0.003996  0.009192
# MALE                 0.000881  0.002235  0.001949  0.003172  0.006254
# OTHER                0.000005  0.000023  0.000014  0.000019  0.000061
# SUM                  0.002525  0.006690  0.004971  0.010536  0.023532
#
# country_destination        GB        IT       NDF        NL        PT  \
# gender
# -unknown-            0.003551  0.004872  0.312343  0.001063  0.000323
# FEMALE               0.004127  0.005111  0.145457  0.001190  0.000365
# MALE                 0.003195  0.003275  0.125176  0.001302  0.000323
# OTHER                0.000014  0.000023  0.000497  0.000014  0.000005
# SUM                  0.010888  0.013282  0.583473  0.003570  0.001017
#
# country_destination        US     other       SUM
# gender
# -unknown-            0.094209  0.016252  0.448290
# FEMALE               0.106319  0.014804  0.295342
# MALE                 0.091154  0.016130  0.255047
# OTHER                0.000543  0.000103  0.001321
# SUM                  0.292226  0.047290  1.000000

# %%
destination_by_gender = pd.DataFrame([])
for gender in df_train.gender.unique():
    gender_mask = df_train.gender == gender
    destination_by_gender = destination_by_gender.append(df_train.loc[gender_mask, 'country_destination'].value_counts(normalize = True).rename(gender))
destination_by_gender['SUM'] = destination_by_gender.agg(np.sum, axis = 1)

# %%
destination_by_gender
# Out:
#                  AU        CA        DE        ES        FR        GB  \
# -unknown-  0.001494  0.005131  0.002968  0.007472  0.017902  0.007922
# MALE       0.003453  0.008762  0.007641  0.012436  0.024522  0.012528
# FEMALE     0.003284  0.007218  0.005679  0.013531  0.031123  0.013975
# OTHER      0.003546  0.017730  0.010638  0.014184  0.046099  0.010638
#
#                  IT       NDF        NL        PT        US     other  SUM
# -unknown-  0.010869  0.696744  0.002372  0.000721  0.210152  0.036253  1.0
# MALE       0.012840  0.490797  0.005107  0.001267  0.357403  0.063244  1.0
# FEMALE     0.017306  0.492505  0.004029  0.001237  0.359988  0.050126  1.0
# OTHER      0.017730  0.375887  0.010638  0.003546  0.411348  0.078014  1.0

# %%
gender_country = defaultdict(list)
for gender in df_train.gender.unique():
    gender_country[gender] = df_train.loc[df_train.gender == gender, 'country_destination'].value_counts()

# %%
barWidth = 0.25

colors = ['#0F4C81', '#F5B895', '#77202F', '#E38690']

plt.figure(figsize=(16,6))

r1 = np.arange(len(gender_country['-unknown-']))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

plt.bar(r1, gender_country['-unknown-'], color='#F67280', width=barWidth, edgecolor='white', label='UNKNOWN')
plt.bar(r2, gender_country['FEMALE'], color='#C06C84', width=barWidth, edgecolor='white', label='FEMALE')
plt.bar(r3, gender_country['MALE'], color='#6C5B7B', width=barWidth, edgecolor='white', label='MALE')
plt.bar(r4, gender_country['OTHER'] , color='#355C7D', width=barWidth, edgecolor='white', label='OTHER')

plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(gender_country['FEMALE']))], df_train.country_destination.unique())
plt.legend(framealpha=1, frameon=True);
plt.show()

# %%
pd.crosstab(df_train.gender, df_train.first_device_type).plot.bar()

# %%
booked_mask = (df_train.date_first_booking.notnull())
age_mask = (df_train.age != -1)

# %%
df_train.loc[booked_mask & age_mask]
# Out:
#                 id date_account_created  timestamp_first_active  \
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# 5       osr2jwljor           2010-01-01          20100101215619
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# ...            ...                  ...                     ...
# 213415  7plqriggxp           2014-06-30          20140630230136
# 213439  msucfwmlzc           2014-06-30          20140630234729
# 213441  omlc9iku7t           2014-06-30          20140630235151
# 213443  0k26r3mir0           2014-06-30          20140630235340
# 213445  qbxza0xojf           2014-06-30          20140630235547
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213415         2014-06-30  -unknown-  55.0         basic            0
# 213439         2015-03-16       MALE  43.0         basic            0
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# ...         ...               ...                ...                     ...
# 213415       en         sem-brand             google                     omg
# 213439       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213443       en         sem-brand             google                  linked
# 213445       en         sem-brand             google                     omg
#
#        signup_app first_device_type first_browser country_destination  booked
# 2             Web   Windows Desktop            IE                  US    True
# 3             Web       Mac Desktop       Firefox               other    True
# 4             Web       Mac Desktop        Chrome                  US    True
# 5             Web       Mac Desktop        Chrome                  US    True
# 6             Web       Mac Desktop        Safari                  US    True
# ...           ...               ...           ...                 ...     ...
# 213415        Web    Android Tablet            IE                  FR    True
# 213439        Web   Windows Desktop       Firefox                  US    True
# 213441        Web       Mac Desktop        Chrome                  ES    True
# 213443        Web       Mac Desktop        Safari                  US    True
# 213445        Web   Windows Desktop            IE                  US    True
#
# [88908 rows x 17 columns]

# %%
#gender_mask = (df_train.gender == '-unknown-')
age_mask = (df_train.age != -1)

# %%
dates = df_train.loc[df_train.date_first_booking.notnull()]
_delta = (pd.DatetimeIndex(dates['date_first_booking']) - pd.DatetimeIndex(dates['date_account_created'])).days
_delta = [day for day in _delta if day >= 0]

# %%
plt.figure(figsize=(16,6))
plt.hist(_delta, bins = 365)
plt.show()

# %% [markdown]
# Which of these channels are bringing you most conversions?

# %%
conversion_rate = df_train.groupby(['affiliate_channel', 'booked']).size() / df_train.groupby(['affiliate_channel']).size()

# %%
conversion_rate.unstack().sort_values(by = True, ascending = False)
# Out:
# booked                False     True
# affiliate_channel
# seo                0.543461  0.456539
# direct             0.568727  0.431273
# sem-brand          0.574045  0.425955
# other              0.598259  0.401741
# sem-non-brand      0.620569  0.379431
# api                0.658994  0.341006
# remarketing        0.664234  0.335766
# content            0.858663  0.141337

# %%
len(df_train[df_train.booked == True]) / len(df_train)
# Out:
# 0.4165265095970504
