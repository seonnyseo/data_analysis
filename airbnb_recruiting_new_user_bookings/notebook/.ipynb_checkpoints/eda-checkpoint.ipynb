# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
from collections import defaultdict

# %%
from tqdm import tqdm

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.write_html('first_figure.html', auto_open=True)

# %% [markdown]
# Data Load & Preprocess

# %%
df_train = pd.read_csv('../data/train_users.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
df_test = pd.read_csv('../data/test_users.csv')

# %%
len(df_train.date_first_booking.dropna())
# Out:
# 88908

# %%
len(df_train.loc[df_train.country_destination != 'NDF'])
# Out:
# 88908

# %%
#df_train = df_train.drop(columns = ['date_first_booking'], axis = 1)

# %%
users = pd.concat([df_train, df_test], sort = False)

# %%
df_train['booked'] = df_train.date_first_booking.notnull()

# %% [markdown]
# DatetimeIndex

# %% [markdown]
# User Acquisition

# %%
#df_train['date_account_created'] = pd.to_datetime(date_account_created, format='%Y-%m-%d', errors='ignore')
users['account_created_year'] = pd.DatetimeIndex(users['date_account_created']).year
users['account_created_month'] = pd.DatetimeIndex(users['date_account_created']).month
users['account_created_day'] = pd.DatetimeIndex(users['date_account_created']).day

# %%
y = users.groupby('account_created_year').size()
x = y.index

plt.figure(figsize=(16,4))
plt.bar(x, y)
plt.grid(alpha = 0.2)
plt.show()

# %% [markdown]
# df.groupby().size()

# %%
year_month = users.groupby(['account_created_year', 'account_created_month']).size()

# %%
from collections import defaultdict

# %% [markdown]
# defaultdict(lambda :) -> lambda 작성하는 법

# %%
account_year_month = defaultdict(lambda: [-1 for x in range(13)])
for idx, val in zip(year_month.index, year_month):
    year = idx[0]
    month = idx[1]
    account_year_month[year][month] = val

# %%
fig, axes = plt.subplots(len(account_year_month.keys()), 1)

for year, ax in zip(account_year_month.keys(), axes):
    
    vals = account_year_month[year]
    start = next(x for x, val in enumerate(vals) if val != -1)
    end = next(x for x, val in enumerate(vals[::-1]) if val != -1)
    
    start = start if start != 0 else 1
    end = end if end != 0 else 13

    ax.plot([m for m in range(len(vals))], vals)
    ax.set_title(year, loc = 'left')

# %%
def draw_line_plot(data):
    plt.figure(figsize=(16,8))
    for year in data.keys():
        start = next(x for x, val in enumerate(data[year]) if val != -1)
        end = next(x for x, val in enumerate(data[year][::-1]) if val != -1)

        start = start if start != 0 else 1
        end = end if end != 0 else 13
        
        plt.plot([x for x in range(start, end)], data[year][start:end], label = year)
    
    plt.xticks([x for x in range(start, end)])

# %%
draw_line_plot(account_year_month)

# %%
activation = pd.DataFrame(users.groupby(['account_created_year', 'account_created_month']).size())
activation = activation.rename(columns = {0:'number_of_users'})

# %%
plt.figure(figsize=(16, 5))  
x = ['{}-{:02}'.format(y, m) for (y, m) in activation.index]
y = activation['number_of_users']
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.grid(alpha = 0.5)
plt.show()

# %% [markdown]
# Affiliate Channel

# %%
users.affiliate_channel.unique()
# Out:
# array(['direct', 'seo', 'other', 'sem-non-brand', 'content', 'sem-brand',
#        'remarketing', 'api'], dtype=object)

# %%
affi_channel_month = users.groupby(['account_created_year', 'account_created_month','affiliate_channel']).size().unstack()
affi_channel_month = affi_channel_month.fillna(0)

# %%
month_range = ['{}-{:02}'.format(y, m) for (y, m) in affi_channel_month.index]

# %%
channel_count = defaultdict(list)
for channel in affi_channel_month.columns:
    for m in range(len(affi_channel_month[channel])):
        count = affi_channel_month[channel][m]
        channel_count[channel].append(count)

# %%
plt.figure(figsize=(16,8))
for channel in channel_count.keys():
    plt.plot(month_range, channel_count[channel], label = channel)
plt.xticks(rotation = 90)
plt.legend(framealpha=1, frameon=True);
plt.grid(alpha=0.5)
plt.show()

# %%
count_by_month = pd.DataFrame.from_dict(channel_count, orient = 'index', columns = x)

# %%
add = pd.DataFrame([])
for idx in range(1, len(x)):
    previous = month_range[idx - 1]
    current = month_range[idx]
    add = pd.concat([add, pd.DataFrame(count_by_month[current] / count_by_month[previous], columns = [current])], axis = 1)

# %%
def color_negative_red(value):
    """
    Colors elements in a dateframe
    green if positive and red if
    negative. Does not color NaN
    values.
    """
    
    if value == 0:
        color = 'black'
    elif value >= 1:
        color = 'red'
    else:
        color = 'blue'
    return 'color: %s'%color

# %%
add.replace(np.inf, np.nan).round(2).fillna(0).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col0 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col1 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col2 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col3 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col4 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col5 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col6 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col7 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col8 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col9 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col10 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col11 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col12 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col13 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col14 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col15 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col16 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col17 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col18 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col19 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col20 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col21 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col22 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col23 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col24 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col25 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col26 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col27 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col28 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col29 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col30 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col31 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col32 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col33 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col34 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col35 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col36 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col37 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col38 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col39 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col40 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col41 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col42 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col43 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col44 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col45 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col46 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col47 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col48 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col49 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col50 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col51 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col52 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col53 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col54 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row0_col55 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col0 {
#             color:  black;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col1 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col2 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col3 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col4 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col5 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col6 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col7 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col8 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col9 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col10 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col11 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col12 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col13 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col14 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col15 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col16 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col17 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col18 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col19 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col20 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col21 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col22 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col23 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col24 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col25 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col26 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col27 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col28 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col29 {
#             color:  red;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col30 {
#             color:  blue;
#         }    #T_55ae27a4_8e4c_11ea_97a9_acde48001122row1_col31 {
#             color:  red;

# %% [markdown]
# Which of these channels are bringing you most conversions?

# %%
conversion_rate = df_train.groupby(['affiliate_channel', 'booked']).size() / df_train.groupby(['affiliate_channel']).size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-324-221016f834ed> in <module>
# ----> 1 conversion_rate = df_train.groupby(['affiliate_channel', 'booked']).size() / df_train.groupby(['affiliate_channel']).size()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'booked'

# %%
conversion_rate.unstack().sort_values(by = True, ascending = False)
# Out:
# booked                False     True
# affiliate_channel
# seo                0.543461  0.456539
# direct             0.568727  0.431273
# sem-brand          0.574045  0.425955
# other              0.598259  0.401741
# sem-non-brand      0.620569  0.379431
# api                0.658994  0.341006
# remarketing        0.664234  0.335766
# content            0.858663  0.141337

# %%
y = users.age.dropna().value_counts()
x = y.index

# %%
plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.grid(alpha = 0.5)
plt.xticks(rotation = 90)
plt.yscale("log")

# %% [markdown]
# use of loc

# %%
age_mask = users.age > 1000
users.loc[age_mask, 'age'] = 2015 - users.loc[age_mask, 'age']

# %%
users.loc[(users.age > 100) | (users.age < 18), 'age'] = -1
users.age.fillna(-1, inplace = True)

# %%
y = users.loc[users.age != -1, 'age'].value_counts()
x = y.index

# %%
plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.show()

# %% [markdown]
# Session Data

# %%
sessions = pd.read_csv('../data/sessions.csv')

# %%
sessions = sessions.rename(columns = {'user_id':'id'})

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# id               object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
sessions.isna().sum()
# Out:
# id                 34496
# action             79626
# action_type      1126204
# action_detail    1126204
# device_type            0
# secs_elapsed      136031
# dtype: int64

# %%
sessions = sessions.dropna(subset = ['id'])

# %%
len(sessions)
# Out:
# 10533241

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
sessions['secs_elapsed'] = sessions['secs_elapsed'].fillna(0)

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
len(sessions)
# Out:
# 10533241

# %%
sessions_ids = sessions.id.unique()

# %%
from_train = df_train.loc[df_train.id.isin(sessions_ids), ['id', 'date_account_created']]
from_test = df_test.loc[df_test.id.isin(sessions_ids), ['id', 'date_account_created']]
account_created_date = pd.concat([from_train, from_test], axis = 0)

# %%
sessions['cumulate_secs'] = sessions.groupby('id')['secs_elapsed'].cumsum()
sessions['cumulate_days'] = sessions['cumulate_secs']/60/60//24

# %%
from tqdm import tqdm

# %% [markdown]
# pd.DatetimeIndex -> list를 받음
#
# pd.to_datetime
#
# 여기 차이 알고하는게 좋을 듯 (속도에 영향을 끼침)

# %%
account_date = defaultdict()
for _id, _date in zip(account_created_date['id'], account_created_date['date_account_created']):
    account_date[_id] = pd.to_datetime(_date)

# %% [markdown]
# account_date dictionary -> much faster

# %%
from tqdm import tqdm_notebook as tqdm

# %%
def return_session_date(row):
    _id = row['id']
    _delta = row['cumulate_days']
    
    return account_date[_id] + pd.DateOffset(_delta)

tqdm.pandas()
sessions['session_date'] = sessions.loc[:, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)
# Out:
# /Users/keonhoseo/opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#
# 100%|██████████| 10533241/10533241 [08:35<00:00, 20414.48it/s]

# %%
"""
def return_session_date(row):
    _id = row['id']
    _delta = row['cumulate_days']
    
    _date = pd.DatetimeIndex(account_created_date[account_created_date.id == _id]['date_account_created'])
    _date += pd.DateOffset(_delta)
    
    return _date.date

#from tqdm import tqdm_notebook as tqdm
tqdm.pandas()
sessions['session_date'] = sessions.loc[:4, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)
"""
# Out:
# "\ndef return_session_date(row):\n    _id = row['id']\n    _delta = row['cumulate_days']\n    \n    _date = pd.DatetimeIndex(account_created_date[account_created_date.id == _id]['date_account_created'])\n    _date += pd.DateOffset(_delta)\n    \n    return _date.date\n\n#from tqdm import tqdm_notebook as tqdm\ntqdm.pandas()\nsessions['session_date'] = sessions.loc[:4, ['id', 'cumulate_days']].progress_apply(return_session_date, axis = 1)\n"

# %%
sessions.head(4)
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0

# %%
booked_users_id = df_train.loc[pd.notnull(df_train.date_first_booking), 'id']

# %%
booked_users = sessions.loc[sessions.id.isin(booked_users_id)]
unbooked_users = sessions.loc[~sessions.id.isin(booked_users_id)]

# %%
mask = df_train.date_account_created > df_train.date_first_booking
book_first = df_train.loc[(df_train.id.isin(booked_users_id)) & mask].id
sessions.loc[sessions.id.isin(book_first)]
# Out:
# Empty DataFrame
# Columns: [id, action, action_type, action_detail, device_type, secs_elapsed]
# Index: []

# %%
len(book_first)
# Out:
# 29

# %%
last_day_ids = users.loc[df_train.date_account_created == '2014-06-30'].id
sessions.loc[sessions.id.isin(last_day_ids)].groupby('id')['secs_elapsed'].agg(np.sum).max()/60/60/24
# Out:
# 126.49166666666667

# %%
sessions.cumulate_days.quantile([.15, .25, .5, .75, .99])
# Out:
# 0.15      1.0
# 0.25      3.0
# 0.50     11.0
# 0.75     27.0
# 0.99    122.0
# Name: cumulate_days, dtype: float64

# %% [markdown]
# bringing cumulate_days up is required

# %%
_retention = []
_retention_days = sessions.groupby('id')['cumulate_days'].agg(['max'])
for day in range(0, 121):
    _retention.append(1 - ((_retention_days < day).sum() / len(_retention_days)))

# %%
plt.figure(figsize=(16,8))
plt.plot(range(0, 121), _retention)
#plt.legend()
plt.xticks(range(0,121, 5))
plt.grid(alpha = 0.5)

# %%
booked_users_elapsed = booked_users.groupby('id')['secs_elapsed'].agg(['sum', ('day', lambda x: np.sum(x)/60/60/24)])
unbooked_users_elapsed = unbooked_users.groupby('id')['secs_elapsed'].agg(['sum', ('day', lambda x: np.sum(x)/60/60/24)])

# %%
_booked = []
_unbooked = []
for day in range(0, 121):
    _booked.append(1 - (len(booked_users_elapsed.loc[booked_users_elapsed.day < day]) / len(booked_users_elapsed)))
    _unbooked.append(1 - (len(unbooked_users_elapsed.loc[unbooked_users_elapsed.day < day]) / len(unbooked_users_elapsed)))

# %%
plt.figure(figsize=(16,8))
plt.plot(range(0, 121), _booked, label = 'Booked Users')
plt.plot(range(0, 121), _unbooked, label = 'Unbooked Users')
plt.legend()
plt.xticks(range(0,121, 5))
plt.grid(alpha = 0.5)

# %%
retention = pd.concat([booked_users_elapsed, unbooked_users_elapsed])

# %%
bottom_20 = retention.loc[retention.day < 5].index
top_20 = retention.loc[retention.day > 35].index

# %%
print(len(bottom_20))
print(len(top_20))
# Out:
# 46055
# 19150

# %%
sessions.loc[sessions.id.isin(top_20)].groupby(['id', 'action'])['action_type'].agg('count')
# Out:
# id          action
# 002qnbzfs5  10                   9
#             active              29
#             at_checkpoint        1
#             campaigns            0
#             click               14
#                                 ..
# zzvg4emw5w  personalize         21
#             search_results      26
#             show                28
#             similar_listings    25
#             update               8
# Name: action_type, Length: 433427, dtype: int64

# %%
sessions.loc[sessions.id.isin(bottom_20)].groupby(['id','action'])['action_type'].agg('count')
# Out:
# id          action
# 001wyh0pz8  active               4
#             campaigns            0
#             collections          4
#             create               1
#             index                2
#                                 ..
# zzzlylp57e  personalize          6
#             requested            5
#             search_results      10
#             show                 9
#             similar_listings     9
# Name: action_type, Length: 324600, dtype: int64

# %%
b_20 = sessions.loc[sessions.id.isin(bottom_20)].groupby(['id','action'])['action_type'].agg('count')

# %%
b_20_actions = defaultdict(int)
for idx, count in zip(b_20.index, b_20):
    b_20_actions[idx[1]] += count

# %%
t_20 = sessions.loc[sessions.id.isin(top_20)].groupby(['id','action'])['action_type'].agg('count')
t_20_actions = defaultdict(int)
for idx, count in zip(t_20.index, t_20):
    t_20_actions[idx[1]] += count

# %%
sorted(b_20_actions.items(), key = lambda k_v:k_v[1], reverse = True)
# Out:
# [('show', 151862),
#  ('search', 49172),
#  ('index', 47556),
#  ('personalize', 39373),
#  ('search_results', 35887),
#  ('header_userpic', 34176),
#  ('active', 33786),
#  ('create', 29072),
#  ('update', 26423),
#  ('dashboard', 25724),
#  ('reviews', 24894),
#  ('ajax_refresh_subtotal', 23471),
#  ('social_connections', 23120),
#  ('similar_listings', 15828),
#  ('notifications', 12771),
#  ('collections', 12053),
#  ('authenticate', 10863),
#  ('confirm_email', 9188),
#  ('unavailabilities', 7278),
#  ('ask_question', 7044),
#  ('edit', 6296),
#  ('requested', 5056),
#  ('callback', 4078),
#  ('impressions', 3991),
#  ('listings', 3136),
#  ('travel_plans_current', 3118),
#  ('ajax_check_dates', 3102),
#  ('manage_listing', 2824),
#  ('show_personalize', 2556),
#  ('payment_instruments', 2450),
#  ('cancellation_policies', 2155),
#  ('click', 2148),
#  ('recommendations', 2099),
#  ('identity', 2074),
#  ('payment_methods', 2030),
#  ('settings', 1987),
#  ('custom_recommended_destinations', 1920),
#  ('ajax_lwlb_contact', 1880),
#  ('signup_login', 1876),
#  ('populate_help_dropdown', 1745),
#  ('recommended_listings', 1677),
#  ('edit_verification', 1639),
#  ('qt2', 1543),
#  ('other_hosting_reviews_first', 1524),
#  ('set_user', 1487),
#  ('pending', 1370),
#  ('open_graph_setting', 1355),
#  ('message_to_host_focus', 1339),
#  ('calendar_tab_inner2', 1325),
#  ('new', 1310),
#  ('ajax_get_referrals_amt', 1187),
#  ('login', 1158),
#  ('available', 1134),
#  ('account', 1118),
#  ('verify', 1093),
#  ('view', 895),
#  ('message_to_host_change', 888),
#  ('agree_terms_check', 823),
#  ('referrer_status', 679),
#  ('tos_confirm', 665),
#  ('hosting_social_proof', 636),
#  ('faq', 625),
#  ('references', 598),
#  ('facebook_auto_login', 583),
#  ('my', 562),
#  ('ajax_referral_banner_experiment_type', 518),
#  ('apply_reservation', 505),
#  ('read_policy_click', 499),
#  ('faq_category', 484),
#  ('cancellation_policy_click', 466),
#  ('ajax_referral_banner_type', 444),
#  ('tell_a_friend', 427),
#  ('reviews_new', 419),
#  ('profile_pic', 402),
#  ('phone_number_widget', 387),
#  ('ajax_image_upload', 365),
#  ('connect', 358),
#  ('populate_from_facebook', 321),
#  ('jumio_token', 320),
#  ('create_multiple', 319),
#  ('signup_modal', 316),
#  ('login_modal', 315),
#  ('ajax_photo_widget_form_iframe', 308),
#  ('kba_update', 305),
#  ('payout_preferences', 304),
#  ('coupon_field_focus', 280),
#  ('set_password', 280),
#  ('apply_coupon_click', 252),
#  ('kba', 244),
#  ('handle_vanity_url', 234),
#  ('transaction_history', 226),
#  ('apply_code', 221),
#  ('apply_coupon_error_type', 219),
#  ('apply_coupon_error', 218),
#  ('decision_tree', 216),
#  ('coupon_code_click', 210),
#  ('domains', 202),
#  ('recent_reservations', 199),
#  ('popular', 192),
#  ('travel_plans_previous', 185),
#  ('position', 184),
#  ('languages_multiselect', 178),
#  ('terms', 160),
#  ('privacy', 157),
#  ('request_new_confirm_email', 156),
#  ('contact_new', 152),
#  ('ajax_statsd', 146),
#  ('endpoint_error', 144),
#  ('pending_tickets', 139),
#  ('faq_experiment_ids', 132),
#  ('transaction_history_paginated', 132),
#  ('top_destinations', 129),
#  ('update_notifications', 125),
#  ('complete_status', 124),
#  ('phone_verification_number_submitted_for_sms', 124),
#  ('spoken_languages', 124),
#  ('delete', 119),
#  ('multi', 118),
#  ('itinerary', 118),
#  ('this_hosting_reviews', 115),
#  ('at_checkpoint', 103),
#  ('host_summary', 98),
#  ('phone_verification_number_sucessfully_submitted', 97),
#  ('patch', 97),
#  ('friends', 96),
#  ('supported', 92),
#  ('how_it_works', 92),
#  ('phone_verification_success', 87),
#  ('pay', 87),
#  ('issue', 85),
#  ('authorize', 84),
#  ('glob', 81),
#  ('remove_dashboard_alert', 79),
#  ('show_code', 67),
#  ('forgot_password', 65),
#  ('jumio_redirect', 64),
#  ('recommend', 64),
#  ('my_listings', 64),
#  ('campaigns', 62),
#  ('salute', 61),
#  ('terms_and_conditions', 57),
#  ('mobile_landing_page', 56),
#  ('qt_reply_v2', 55),
#  ('qt_with', 55),
#  ('my_reservations', 54),
#  ('about_us', 53),
#  ('change_currency', 52),
#  ('department', 51),
#  ('trust', 48),
#  ('complete_redirect', 48),
#  ('reputation', 43),
#  ('departments', 38),
#  ('this_hosting_reviews_3000', 35),
#  ('signature', 32),
#  ('requirements', 32),
#  ('why_host', 31),
#  ('photography', 31),
#  ('submit_contact', 30),
#  ('ajax_google_translate_description', 29),
#  ('signup_weibo_referral', 29),
#  ('listing', 28),
#  ('p4_refund_policy_terms', 28),
#  ('phone_verification_error', 28),
#  ('invalid_action', 25),
#  ('update_hide_from_search_engines', 24),
#  ('airbnb_picks', 24),
#  ('ajax_google_translate_reviews', 24),
#  ('office_location', 23),
#  ('other_hosting_reviews', 22),
#  ('clickthrough', 22),
#  ('rate', 22),
#  ('agree_terms_uncheck', 21),
#  ('update_friends_display', 21),
#  ('place_worth', 20),
#  ('apply_coupon_click_success', 20),
#  ('review_page', 20),
#  ('guarantee', 18),
#  ('change_password', 17),
#  ('countries', 16),
#  ('complete', 16),
#  ('10', 15),
#  ('p4_terms', 15),
#  ('weibo_signup_referral_finish', 15),
#  ('email_wishlist', 13),
#  ('webcam_upload', 11),
#  ('locations', 11),
#  ('ajax_payout_options_by_country', 10),
#  ('email_share', 10),
#  ('11', 10),
#  ('hospitality', 9),
#  ('country_options', 9),
#  ('ajax_get_results', 9),
#  ('phone_verification_modal', 8),
#  ('home_safety_landing', 8),
#  ('book', 7),
#  ('redirect', 7),
#  ('detect_fb_session', 7),
#  ('update_country_of_residence', 7),
#  ('phone_verification_number_submitted_for_call', 7),
#  ('upload', 6),
#  ('life', 6),
#  ('create_airbnb', 6),
#  ('push_notification_callback', 6),
#  ('friends_new', 6),
#  ('press_news', 6),
#  ('founders', 6),
#  ('questions', 5),
#  ('ajax_worth', 5),
#  ('jumio', 5),
#  ('destroy', 5),
#  ('views', 5),
#  ('sublets', 5),
#  ('overview', 4),
#  ('ajax_payout_edit', 4),
#  ('apply', 4),
#  ('press_release', 4),
#  ('clear_reservation', 4),
#  ('phone_verification_phone_number_removed', 3),
#  ('receipt', 3),
#  ('host_2013', 3),
#  ('media_resources', 3),
#  ('mobile_oauth_callback', 3),
#  ('zendesk_login_jwt', 3),
#  ('cancel', 3),
#  ('feed', 3),
#  ('ajax_ldp', 3),
#  ('social', 3),
#  ('united-states', 3),
#  ('image_order', 3),
#  ('toggle_archived_thread', 2),
#  ('hospitality_standards', 2),
#  ('concierge', 2),
#  ('badge', 2),
#  ('12', 2),
#  ('payout_update', 2),
#  ('change', 2),
#  ('home_safety_terms', 2),
#  ('unsubscribe', 2),
#  ('localized', 2),
#  ('envoy_form', 2),
#  ('business_travel', 2),
#  ('confirmation', 2),
#  ('localization_settings', 1),
#  ('travel', 1),
#  ('ajax_google_translate', 1),
#  ('multi_message_attributes', 1),
#  ('sldf', 1),
#  ('ajax_special_offer_dates_available', 1),
#  ('toggle_starred_thread', 1),
#  ('reset_calendar', 1),
#  ('new_host', 1),
#  ('unread', 1),
#  ('15', 1),
#  ('wishlists', 1),
#  ('slideshow', 1),
#  ('set_default', 1),
#  ('similar_listings_v2', 0),
#  ('track_page_view', 0),
#  ('lookup', 0),
#  ('currencies', 0),
#  ('signed_out_modal', 0),
#  ('uptodate', 0),
#  ('braintree_client_token', 0)]

# %%
sorted(t_20_actions.items(), key = lambda k_v:k_v[1], reverse = True)
# Out:
# [('show', 921731),
#  ('index', 401718),
#  ('personalize', 340626),
#  ('search_results', 336316),
#  ('ajax_refresh_subtotal', 238514),
#  ('similar_listings', 184393),
#  ('search', 180431),
#  ('update', 160632),
#  ('social_connections', 129528),
#  ('reviews', 113728),
#  ('active', 59346),
#  ('edit', 46877),
#  ('collections', 46149),
#  ('dashboard', 44451),
#  ('create', 42479),
#  ('qt2', 42423),
#  ('header_userpic', 31642),
#  ('unavailabilities', 29279),
#  ('ajax_check_dates', 24322),
#  ('show_personalize', 24096),
#  ('calendar_tab_inner2', 23759),
#  ('identity', 22840),
#  ('listings', 22775),
#  ('notifications', 17783),
#  ('requested', 15782),
#  ('ajax_lwlb_contact', 15588),
#  ('other_hosting_reviews_first', 15497),
#  ('ask_question', 15379),
#  ('travel_plans_current', 15228),
#  ('edit_verification', 14996),
#  ('confirm_email', 14302),
#  ('complete_status', 13454),
#  ('manage_listing', 12474),
#  ('recommendations', 11524),
#  ('authenticate', 10308),
#  ('ajax_photo_widget_form_iframe', 10194),
#  ('click', 9939),
#  ('payment_instruments', 9112),
#  ('impressions', 8411),
#  ('payment_methods', 8189),
#  ('verify', 7331),
#  ('message_to_host_focus', 7080),
#  ('profile_pic', 7056),
#  ('cancellation_policies', 6582),
#  ('custom_recommended_destinations', 6293),
#  ('populate_help_dropdown', 6178),
#  ('qt_reply_v2', 5968),
#  ('my', 5967),
#  ('ajax_image_upload', 5771),
#  ('settings', 5493),
#  ('callback', 5173),
#  ('references', 5168),
#  ('kba_update', 5152),
#  ('pending', 5034),
#  ('view', 4866),
#  ('message_to_host_change', 4398),
#  ('ajax_get_referrals_amt', 4385),
#  ('connect', 4295),
#  ('faq', 4274),
#  ('new', 4050),
#  ('apply_reservation', 4003),
#  ('populate_from_facebook', 3773),
#  ('jumio_token', 3772),
#  ('handle_vanity_url', 3589),
#  ('account', 3550),
#  ('agree_terms_check', 3503),
#  ('recommended_listings', 3463),
#  ('kba', 3267),
#  ('request_new_confirm_email', 3182),
#  ('coupon_field_focus', 2971),
#  ('status', 2788),
#  ('faq_category', 2774),
#  ('phone_number_widget', 2759),
#  ('push_notification_callback', 2660),
#  ('available', 2631),
#  ('payout_preferences', 2565),
#  ('delete', 2539),
#  ('reviews_new', 2456),
#  ('apply_coupon_click', 2401),
#  ('10', 2397),
#  ('languages_multiselect', 2338),
#  ('jumio_redirect', 2297),
#  ('apply_coupon_error', 2199),
#  ('apply_coupon_error_type', 2189),
#  ('this_hosting_reviews', 2151),
#  ('at_checkpoint', 1945),
#  ('complete_redirect', 1945),
#  ('ajax_referral_banner_type', 1826),
#  ('ajax_referral_banner_experiment_type', 1826),
#  ('set_user', 1821),
#  ('open_graph_setting', 1797),
#  ('endpoint_error', 1729),
#  ('signup_login', 1549),
#  ('hosting_social_proof', 1538),
#  ('12', 1526),
#  ('host_summary', 1451),
#  ('decision_tree', 1443),
#  ('facebook_auto_login', 1440),
#  ('recent_reservations', 1327),
#  ('referrer_status', 1211),
#  ('pay', 1141),
#  ('read_policy_click', 1127),
#  ('signature', 1097),
#  ('phone_verification_number_submitted_for_sms', 1084),
#  ('login', 1059),
#  ('tell_a_friend', 1040),
#  ('itinerary', 1037),
#  ('contact_new', 1031),
#  ('coupon_code_click', 1026),
#  ('cancellation_policy_click', 974),
#  ('ajax_statsd', 973),
#  ('qt_with', 949),
#  ('transaction_history', 938),
#  ('privacy', 926),
#  ('phone_verification_number_sucessfully_submitted', 871),
#  ('15', 833),
#  ('popular', 818),
#  ('phone_verification_modal', 778),
#  ('this_hosting_reviews_3000', 767),
#  ('change', 761),
#  ('update_cached', 752),
#  ('add_note', 734),
#  ('phone_verification_success', 676),
#  ('complete', 675),
#  ('supported', 662),
#  ('patch', 655),
#  ('update_notifications', 616),
#  ('terms', 594),
#  ('tos_confirm', 594),
#  ('login_modal', 587),
#  ('spoken_languages', 585),
#  ('pending_tickets', 569),
#  ('create_multiple', 568),
#  ('ajax_google_translate_reviews', 567),
#  ('glob', 545),
#  ('ajax_payout_edit', 533),
#  ('signup_modal', 510),
#  ('authorize', 505),
#  ('set_password', 503),
#  ('ajax_google_translate_description', 500),
#  ('ajax_payout_options_by_country', 488),
#  ('top_destinations', 483),
#  ('transaction_history_paginated', 483),
#  ('upload', 461),
#  ('domains', 442),
#  ('11', 434),
#  ('phone_verification_error', 429),
#  ('other_hosting_reviews', 422),
#  ('requirements', 418),
#  ('issue', 398),
#  ('photography', 382),
#  ('my_listings', 377),
#  ('faq_experiment_ids', 373),
#  ('cancel', 370),
#  ('review_page', 370),
#  ('trust', 357),
#  ('webcam_upload', 344),
#  ('payout_update', 343),
#  ('receipt', 306),
#  ('phone_verification_number_submitted_for_call', 300),
#  ('toggle_archived_thread', 299),
#  ('remove_dashboard_alert', 281),
#  ('listing', 277),
#  ('image_order', 272),
#  ('forgot_password', 270),
#  ('friends', 263),
#  ('friends_new', 262),
#  ('overview', 257),
#  ('mobile_oauth_callback', 254),
#  ('my_reservations', 253),
#  ('rate', 243),
#  ('mobile_landing_page', 235),
#  ('ajax_get_results', 234),
#  ('change_currency', 227),
#  ('agree_terms_uncheck', 222),
#  ('ajax_google_translate', 221),
#  ('how_it_works', 218),
#  ('guest_booked_elsewhere', 195),
#  ('travel_plans_previous', 195),
#  ('apply_code', 185),
#  ('email_wishlist', 179),
#  ('position', 174),
#  ('jumio', 159),
#  ('become_user', 156),
#  ('toggle_starred_thread', 150),
#  ('email_share', 146),
#  ('about_us', 138),
#  ('relationship', 137),
#  ('book', 117),
#  ('ajax_price_and_availability', 111),
#  ('p4_refund_policy_terms', 109),
#  ('destroy', 108),
#  ('terms_and_conditions', 108),
#  ('apply_coupon_click_success', 107),
#  ('campaigns', 106),
#  ('airbnb_picks', 105),
#  ('clickthrough', 101),
#  ('department', 101),
#  ('country_options', 99),
#  ('countries', 96),
#  ('update_hide_from_search_engines', 92),
#  ('submit_contact', 91),
#  ('phone_verification_phone_number_removed', 91),
#  ('guarantee', 90),
#  ('salute', 86),
#  ('phone_verification_call_taking_too_long', 83),
#  ('p4_terms', 79),
#  ('email_itinerary_colorbox', 79),
#  ('change_password', 78),
#  ('multi', 76),
#  ('home_safety_landing', 71),
#  ('update_friends_display', 68),
#  ('invalid_action', 62),
#  ('show_code', 61),
#  ('departments', 60),
#  ('office_location', 59),
#  ('why_host', 55),
#  ('popular_listing', 54),
#  ('clear_reservation', 46),
#  ('request_photography', 46),
#  ('update_reservation_requirements', 44),
#  ('payoneer_account_redirect', 41),
#  ('print_confirmation', 38),
#  ('create_airbnb', 38),
#  ('reservation', 35),
#  ('recommend', 35),
#  ('add_guests', 34),
#  ('change_availability', 34),
#  ('hospitality', 33),
#  ('guest_billing_receipt', 33),
#  ('new_session', 32),
#  ('create_ach', 31),
#  ('create_paypal', 31),
#  ('update_country_of_residence', 28),
#  ('unread', 24),
#  ('locations', 24),
#  ('acculynk_session_obtained', 24),
#  ('press_release', 23),
#  ('acculynk_bin_check_success', 23),
#  ('multi_message', 22),
#  ('acculynk_load_pin_pad', 22),
#  ('place_worth', 21),
#  ('social', 21),
#  ('multi_message_attributes', 21),
#  ('support_phone_numbers', 20),
#  ('payoneer_signup_complete', 20),
#  ('founders', 19),
#  ('united-states', 18),
#  ('hospitality_standards', 18),
#  ('slideshow', 18),
#  ('zendesk_login_jwt', 16),
#  ('press_news', 16),
#  ('home_safety_terms', 15),
#  ('signup_weibo_referral', 15),
#  ('ajax_worth', 14),
#  ('has_profile_pic', 13),
#  ('badge', 13),
#  ('host_2013', 12),
#  ('concierge', 12),
#  ('detect_fb_session', 12),
#  ('google_importer', 12),
#  ('load_more', 11),
#  ('acculynk_pin_pad_inactive', 10),
#  ('ajax_send_message', 9),
#  ('weibo_signup_referral_finish', 9),
#  ('approve', 9),
#  ('email_by_key', 8),
#  ('views', 8),
#  ('set_default', 8),
#  ('respond', 8),
#  ('sublets', 8),
#  ('localization_settings', 7),
#  ('press_content', 7),
#  ('localized', 7),
#  ('ajax_payout_split_edit', 7),
#  ('change_default_payout', 7),
#  ('business_travel', 7),
#  ('media_resources', 6),
#  ('onenight', 6),
#  ('maybe_information', 6),
#  ('add_guest_colorbox', 6),
#  ('pricing', 6),
#  ('life', 6),
#  ('city_count', 6),
#  ('feed', 6),
#  ('social-media', 5),
#  ('redirect', 5),
#  ('rentals', 5),
#  ('acculynk_pin_pad_success', 5),
#  ('add_business_address_colorbox', 4),
#  ('photography_update', 3),
#  ('sync', 3),
#  ('envoy_form', 3),
#  ('locale_from_host', 3),
#  ('ajax_photo_widget', 3),
#  ('toggle_availability', 3),
#  ('payout_delete', 3),
#  ('airbrb', 3),
#  ('booking', 3),
#  ('preapproval', 2),
#  ('stpcv', 2),
#  ('ajax_ldp', 2),
#  ('ajax_special_offer_dates_available', 2),
#  ('views_campaign', 2),
#  ('sandy', 2),
#  ('accept_decline', 2),
#  ('refund_guest_cancellation', 2),
#  ('reputation', 2),
#  ('special_offer', 2),
#  ('host_cancel', 1),
#  ('currencies', 1),
#  ('recommendation_page', 1),
#  ('hard_fallback_submit', 1),
#  ('open_hard_fallback_modal', 1),
#  ('revert_to_admin', 1),
#  ('set_minimum_payout_amount', 1),
#  ('acculynk_pin_pad_error', 1),
#  ('envoy_bank_details_redirect', 1),
#  ('acculynk_bin_check_failed', 1),
#  ('reset_calendar', 1),
#  ('message', 1),
#  ('desks', 1),
#  ('deauthorize', 1),
#  ('travel', 1),
#  ('events', 1),
#  ('lookup', 0),
#  ('track_page_view', 0),
#  ('similar_listings_v2', 0),
#  ('signed_out_modal', 0),
#  ('uptodate', 0),
#  ('check', 0),
#  ('braintree_client_token', 0),
#  ('phone_verification', 0),
#  ('widget', 0),
#  ('satisfy', 0),
#  ('track_activity', 0)]

# %%
action_count = sessions.groupby(['id', 'action'])['action_type'].agg('count')

# %%
action_count.unstack().loc[action_count.unstack()['confirm_email'] > 1]['confirm_email'].mean()
# Out:
# 2.4192238267148016

# %%
action_count.unstack().loc[action_count.unstack()['confirm_email'] > 1]['confirm_email'].max()
# Out:
# 18.0

# %% [markdown]
# MAU (Monthly Active Users)

# %%
daily_access = sessions.groupby(['id', 'session_date'])['action'].agg('nunique')

# %%
daily_access.reset_index()['session_date']
# Out:
# 0         2014-05-14
# 1         2014-05-15
# 2         2014-05-16
# 3         2014-05-23
# 4         2014-05-24
#              ...
# 1335185   2014-06-11
# 1335186   2014-06-12
# 1335187   2014-06-13
# 1335188   2014-06-14
# 1335189   2014-06-15
# Name: session_date, Length: 1335190, dtype: datetime64[ns]

# %% [markdown]
# DAU

# %%
dau = daily_access.reset_index()['session_date'].value_counts()

# %%
plt.figure(figsize=(16,7))
plt.bar(dau.index, dau)
plt.grid(alpha = 0.3)
plt.show()

# %%
_year = pd.DatetimeIndex(daily_access.reset_index()['session_date']).year
_month = pd.DatetimeIndex(daily_access.reset_index()['session_date']).month

# %%
y = pd.crosstab(_year, _month).stack()
x = ['{}-{:02}'.format(year, month) for (year, month) in y.index]

plt.figure(figsize=(16,6))
plt.bar(x, y)
plt.xticks(rotation = 90)
plt.grid(alpha = 0.2)
plt.show()

# %%
t = sessions.action.value_counts()
for idx, c in zip(t.index, t):
    print(idx, c)
# Out:
# show 2758985
# index 841071
# search_results 723124
# personalize 704782
# search 533833
# ajax_refresh_subtotal 486414
# similar_listings 363423
# update 362708
# social_connections 337764
# reviews 319318
# active 187370
# similar_listings_v2 168457
# lookup 161422
# create 155233
# dashboard 152515
# header_userpic 141315
# collections 124067
# edit 108927
# campaigns 104647
# track_page_view 80949
# unavailabilities 77985
# qt2 64585
# notifications 59198
# confirm_email 58557
# requested 57020
# identity 53550
# ajax_check_dates 52426
# show_personalize 50353
# ask_question 43972
# listings 43515
# authenticate 42841
# calendar_tab_inner2 41947
# travel_plans_current 38139
# edit_verification 33374
# ajax_lwlb_contact 33345
# other_hosting_reviews_first 30996
# recommendations 30497
# impressions 27746
# manage_listing 26267
# click 25456
# complete_status 24667
# ajax_photo_widget_form_iframe 24425
# payment_instruments 23461
# message_to_host_focus 21629
# verify 21324
# payment_methods 19736
# cancellation_policies 19220
# callback 19053
# settings 16740
# custom_recommended_destinations 16507
# pending 15987
# profile_pic 15794
# populate_help_dropdown 15259
# message_to_host_change 14219
# ajax_image_upload 13546
# view 13088
# kba_update 12681
# references 11385
# my 11286
# ajax_get_referrals_amt 11278
# new 10988
# agree_terms_check 10934
# apply_reservation 10911
# connect 10089
# recommended_listings 9982
# faq 9456
# populate_from_facebook 9179
# account 9004
# available 8674
# jumio_token 8667
# qt_reply_v2 8529
# signup_login 8384
# request_new_confirm_email 7932
# handle_vanity_url 7914
# kba 7909
# coupon_field_focus 7604
# phone_number_widget 7311
# open_graph_setting 7205
# set_user 6885
# faq_category 6564
# apply_coupon_click 6219
# reviews_new 5820
# apply_coupon_error 5563
# apply_coupon_error_type 5547
# languages_multiselect 5400
# localization_settings 5391
# at_checkpoint 5166
# jumio_redirect 5146
# delete 5021
# ajax_referral_banner_experiment_type 4912
# login 4801
# endpoint_error 4765
# payout_preferences 4541
# complete_redirect 4504
# status 4480
# ajax_referral_banner_type 4444
# hosting_social_proof 4344
# referrer_status 4250
# facebook_auto_login 3980
# read_policy_click 3900
# this_hosting_reviews 3859
# cancellation_policy_click 3455
# uptodate 3329
# push_notification_callback 3327
# tell_a_friend 3302
# 10 3202
# phone_verification_number_submitted_for_sms 2963
# coupon_code_click 2944
# tos_confirm 2935
# decision_tree 2726
# recent_reservations 2461
# phone_verification_number_sucessfully_submitted 2460
# pay 2292
# 12 2204
# popular 2151
# host_summary 2106
# create_multiple 2094
# phone_verification_success 2030
# transaction_history 2029
# login_modal 1973
# terms 1941
# privacy 1939
# ajax_statsd 1916
# itinerary 1870
# signup_modal 1830
# signature 1814
# qt_with 1793
# contact_new 1784
# patch 1577
# set_password 1568
# phone_verification_modal 1558
# domains 1528
# spoken_languages 1469
# this_hosting_reviews_3000 1375
# update_notifications 1315
# supported 1275
# top_destinations 1272
# pending_tickets 1263
# glob 1238
# complete 1130
# transaction_history_paginated 1130
# change 1116
# faq_experiment_ids 1085
# signed_out_modal 1054
# 15 1053
# phone_verification_error 1033
# authorize 1029
# position 974
# add_note 960
# ajax_google_translate_reviews 949
# ajax_google_translate_description 931
# issue 863
# update_cached 835
# webcam_upload 815
# remove_dashboard_alert 812
# apply_code 805
# friends 804
# listing 772
# upload 762
# forgot_password 755
# other_hosting_reviews 749
# how_it_works 747
# trust 739
# my_listings 730
# requirements 713
# ajax_payout_edit 711
# 11 702
# phone_verification_number_submitted_for_call 687
# ajax_payout_options_by_country 679
# travel_plans_previous 672
# photography 629
# mobile_landing_page 618
# change_currency 603
# agree_terms_uncheck 597
# cancel 581
# review_page 564
# my_reservations 553
# rate 505
# friends_new 476
# payout_update 467
# receipt 459
# mobile_oauth_callback 434
# image_order 418
# department 417
# about_us 412
# email_wishlist 388
# overview 381
# toggle_archived_thread 380
# recommend 375
# p4_refund_policy_terms 368
# ajax_get_results 367
# terms_and_conditions 329
# multi 328
# apply_coupon_click_success 328
# email_share 319
# jumio 319
# salute 317
# currencies 297
# p4_terms 292
# ajax_google_translate 290
# airbnb_picks 278
# show_code 259
# departments 246
# guarantee 246
# book 243
# submit_contact 241
# clickthrough 238
# update_hide_from_search_engines 226
# destroy 226
# guest_booked_elsewhere 221
# toggle_starred_thread 206
# phone_verification_phone_number_removed 206
# phone_verification_call_taking_too_long 192
# relationship 187
# countries 182
# become_user 180
# ajax_price_and_availability 175
# why_host 174
# change_password 172
# update_friends_display 171
# office_location 163
# country_options 155
# email_itinerary_colorbox 140
# invalid_action 139
# home_safety_landing 134
# braintree_client_token 120
# clear_reservation 119
# check 119
# place_worth 106
# popular_listing 93
# signup_weibo_referral 90
# create_airbnb 86
# hospitality 81
# locations 75
# widget 75
# new_session 69
# print_confirmation 69
# founders 62
# add_guests 60
# update_country_of_residence 59
# request_photography 59
# reputation 57
# ajax_worth 56
# social 55
# update_reservation_requirements 55
# press_release 54
# multi_message 52
# press_news 52
# acculynk_session_obtained 52
# multi_message_attributes 51
# acculynk_bin_check_success 51
# guest_billing_receipt 50
# acculynk_load_pin_pad 50
# detect_fb_session 49
# concierge 47
# create_paypal 47
# hospitality_standards 47
# change_availability 47
# payoneer_account_redirect 45
# weibo_signup_referral_finish 45
# slideshow 40
# unread 40
# create_ach 39
# reservation 38
# redirect 35
# badge 34
# sublets 31
# home_safety_terms 31
# acculynk_pin_pad_inactive 30
# united-states 30
# life 28
# host_2013 27
# zendesk_login_jwt 24
# views 22
# google_importer 22
# payoneer_signup_complete 21
# set_default 21
# ajax_send_message 21
# support_phone_numbers 20
# ajax_ldp 19
# has_profile_pic 18
# phone_verification 16
# onenight 15
# localized 15
# business_travel 14
# press_content 14
# load_more 13
# media_resources 12
# feed 11
# approve 11
# questions 11
# respond 11
# open_hard_fallback_modal 10
# signup_weibo 10
# change_default_payout 9
# satisfy 9
# add_business_address_colorbox 9
# envoy_form 8
# ajax_photo_widget 8
# city_count 8
# email_by_key 8
# ajax_payout_split_edit 7
# social-media 7
# add_guest_colorbox 7
# maybe_information 7
# pricing 7
# rentals 7
# photography_update 6
# new_host 6
# disaster_action 6
# track_activity 6
# sync 5
# travel 5
# apply 5
# acculynk_pin_pad_success 5
# payout_delete 5
# acculynk_pin_pad_error 4
# southern-europe 4
# locale_from_host 4
# hard_fallback_submit 4
# message 4
# booking 4
# ajax_special_offer_dates_available 3
# toggle_availability 3
# airbrb 3
# envoy_bank_details_redirect 2
# stpcv 2
# preapproval 2
# unsubscribe 2
# report 2
# use_mobile_site 2
# confirmation 2
# reset_calendar 2
# views_campaign_rules 2
# accept_decline 2
# rest-of-world 2
# recommendation_page 2
# refund_guest_cancellation 2
# sandy 2
# south-america 2
# friend_listing 2
# tos_2014 2
# views_campaign 2
# special_offer 2
# update_message 1
# reactivate 1
# deauthorize 1
# wishlists 1
# deactivated 1
# deactivate 1
# sldf 1
# host_cancel 1
# desks 1
# acculynk_bin_check_failed 1
# plaxo_cb 1
# set_minimum_payout_amount 1
# nyan 1
# revert_to_admin 1
# events 1

# %%
len(sessions.id.unique())
# Out:
# 135483

# %%
gender_destination = pd.crosstab(df_train.gender, df_train.country_destination, normalize = True)
gender_destination['SUM'] = gender_destination.agg(np.sum, axis = 1)
gender_destination.loc['SUM'] = gender_destination.sum()
gender_destination
# Out:
# country_destination        AU        CA        DE        ES        FR  \
# gender
# -unknown-            0.000670  0.002300  0.001331  0.003350  0.008025
# FEMALE               0.000970  0.002132  0.001677  0.003996  0.009192
# MALE                 0.000881  0.002235  0.001949  0.003172  0.006254
# OTHER                0.000005  0.000023  0.000014  0.000019  0.000061
# SUM                  0.002525  0.006690  0.004971  0.010536  0.023532
#
# country_destination        GB        IT       NDF        NL        PT  \
# gender
# -unknown-            0.003551  0.004872  0.312343  0.001063  0.000323
# FEMALE               0.004127  0.005111  0.145457  0.001190  0.000365
# MALE                 0.003195  0.003275  0.125176  0.001302  0.000323
# OTHER                0.000014  0.000023  0.000497  0.000014  0.000005
# SUM                  0.010888  0.013282  0.583473  0.003570  0.001017
#
# country_destination        US     other       SUM
# gender
# -unknown-            0.094209  0.016252  0.448290
# FEMALE               0.106319  0.014804  0.295342
# MALE                 0.091154  0.016130  0.255047
# OTHER                0.000543  0.000103  0.001321
# SUM                  0.292226  0.047290  1.000000

# %%
destination_by_gender = pd.DataFrame([])
for gender in df_train.gender.unique():
    gender_mask = df_train.gender == gender
    destination_by_gender = destination_by_gender.append(df_train.loc[gender_mask, 'country_destination'].value_counts(normalize = True).rename(gender))
destination_by_gender['SUM'] = destination_by_gender.agg(np.sum, axis = 1)

# %%
destination_by_gender
# Out:
#                  AU        CA        DE        ES        FR        GB  \
# -unknown-  0.001494  0.005131  0.002968  0.007472  0.017902  0.007922
# MALE       0.003453  0.008762  0.007641  0.012436  0.024522  0.012528
# FEMALE     0.003284  0.007218  0.005679  0.013531  0.031123  0.013975
# OTHER      0.003546  0.017730  0.010638  0.014184  0.046099  0.010638
#
#                  IT       NDF        NL        PT        US     other  SUM
# -unknown-  0.010869  0.696744  0.002372  0.000721  0.210152  0.036253  1.0
# MALE       0.012840  0.490797  0.005107  0.001267  0.357403  0.063244  1.0
# FEMALE     0.017306  0.492505  0.004029  0.001237  0.359988  0.050126  1.0
# OTHER      0.017730  0.375887  0.010638  0.003546  0.411348  0.078014  1.0

# %%
gender_country = defaultdict(list)
for gender in df_train.gender.unique():
    gender_country[gender] = df_train.loc[df_train.gender == gender, 'country_destination'].value_counts()

# %%
barWidth = 0.25

colors = ['#0F4C81', '#F5B895', '#77202F', '#E38690']

plt.figure(figsize=(16,6))

r1 = np.arange(len(gender_country['-unknown-']))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

plt.bar(r1, gender_country['-unknown-'], color='#F67280', width=barWidth, edgecolor='white', label='UNKNOWN')
plt.bar(r2, gender_country['FEMALE'], color='#C06C84', width=barWidth, edgecolor='white', label='FEMALE')
plt.bar(r3, gender_country['MALE'], color='#6C5B7B', width=barWidth, edgecolor='white', label='MALE')
plt.bar(r4, gender_country['OTHER'] , color='#355C7D', width=barWidth, edgecolor='white', label='OTHER')

plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(gender_country['FEMALE']))], df_train.country_destination.unique())
plt.legend(framealpha=1, frameon=True);
plt.show()

# %%
pd.crosstab(df_train.gender, df_train.first_device_type).plot.bar()

# %%
#gender_mask = (df_train.gender == '-unknown-')
age_mask = (df_train.age != -1)

# %%
df_train.loc[age_mask, 'gender'].value_counts()
# Out:
# FEMALE       56695
# MALE         49949
# -unknown-    16119
# OTHER          224
# Name: gender, dtype: int64

# %%
age_mask = (df_train.age == -1)
df_train.loc[age_mask, 'gender'].value_counts()
# Out:
# -unknown-    79569
# FEMALE        6346
# MALE          4491
# OTHER           58
# Name: gender, dtype: int64

# %%
dates = df_train.loc[df_train.date_first_booking.notnull()]
_delta = (pd.DatetimeIndex(dates['date_first_booking']) - pd.DatetimeIndex(dates['date_account_created'])).days
_delta = [day for day in _delta if day >= 0]

# %%
plt.figure(figsize=(16,6))
plt.hist(_delta, bins = 365)
plt.show()
